# %% [markdown]
# # 제주도 식당의 리뷰와 정보들을 네이버에서 크롤링해오기
# - 제주도식당_전처리.csv를 사용

# %%
import pandas as pd
import random
import time

import warnings
warnings.filterwarnings('ignore')
from selenium import webdriver  # 동적크롤링
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By
from bs4 import BeautifulSoup
# Out:
# C:\Users\clclc\AppData\Local\Temp\ipykernel_15688\1771813411.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %% [markdown]
# ### 크롤링에 필요한 데이터 불러오기

# %%
df = pd.read_csv("Data/제주도식당_전처리.csv", index_col=False)

# %%
df.head()
# Out:
#          사업장명 업종구분대분류   업종구분소분류                        소재지전체주소  \
# 0      탑동에이치지   일반음식점        기타        제주특별자치도 제주시 삼도이동 1120-2
# 1    에릭스에스프레소   일반음식점        기타   제주특별자치도 제주시 구좌읍 세화리 1397-6번지
# 2    일품순두부한림점   일반음식점        한식   제주특별자치도 제주시 한림읍 대림리 1845-2번지
# 3  김복남맥주제주아라점   일반음식점  식육(숯불구이)          제주특별자치도 제주시 아라일동 6139
# 4       봉플라봉뱅   일반음식점        기타  제주특별자치도 제주시 연동 312-57번지 정인하우스
#
#                                도로명전체주소         lat          lng
# 0      제주특별자치도 제주시 무근성안길 16, 1층 (삼도이동)  33.5151128  126.5202001
# 1           제주특별자치도 제주시 구좌읍 구좌로 77, 1층  33.5214225  126.8588743
# 2         제주특별자치도 제주시 한림읍 한림상로 237, 1층  33.4192601  126.2674304
# 3   제주특별자치도 제주시 중앙로 581, 에이동 1층 (아라일동)  33.4714278  126.5457848
# 4  제주특별자치도 제주시 문송1길 6-1, 정인하우스 1층 (연동)  33.4879976  126.4978933

# %% [markdown]
# ### 크롤링에 필요한 컬럼만 뽑아서 저장하기

# %%
scrapy_df = df[["사업장명", "도로명전체주소"]]

# %%
scrapy_df.head()
# Out:
#          사업장명                              도로명전체주소
# 0      탑동에이치지      제주특별자치도 제주시 무근성안길 16, 1층 (삼도이동)
# 1    에릭스에스프레소           제주특별자치도 제주시 구좌읍 구좌로 77, 1층
# 2    일품순두부한림점         제주특별자치도 제주시 한림읍 한림상로 237, 1층
# 3  김복남맥주제주아라점   제주특별자치도 제주시 중앙로 581, 에이동 1층 (아라일동)
# 4       봉플라봉뱅  제주특별자치도 제주시 문송1길 6-1, 정인하우스 1층 (연동)

# %% [markdown]
# ### 네이버 지도창에서 검색할 때 정확도를 높이기 위해 도로명 주소의 , 뒤에는 제거
# > 이유는 네이버 지도탭에서 검색시 "사업장명" + "도로명전체주소" 형식으로 검색하면 정확히 원하는 식당이 뜨는 빈도수가 높기 때문에
# 도로명전체주소가 필요한 것인데, 문제는 도로명주소에 상세주소가 적혀있으면 검색이 안될 확률이 높았음
# 때문에 ','뒤에 있는 상세주소를 제거할 필요가 있음

# %%
scrapy_df['도로명전체주소'] = scrapy_df['도로명전체주소'].str.split(',', n=1).str[0]

# %%
scrapy_df.head()
# Out:
#          사업장명                   도로명전체주소
# 0      탑동에이치지      제주특별자치도 제주시 무근성안길 16
# 1    에릭스에스프레소    제주특별자치도 제주시 구좌읍 구좌로 77
# 2    일품순두부한림점  제주특별자치도 제주시 한림읍 한림상로 237
# 3  김복남맥주제주아라점       제주특별자치도 제주시 중앙로 581
# 4       봉플라봉뱅      제주특별자치도 제주시 문송1길 6-1

# %% [markdown]
# ---
# ## 크롤링하기

# %%
# 크롬 드라이버 실행
# chrome_options = webdriver.ChromeOptions()
# driver = webdriver.Chrome(options=chrome_options)
driver = webdriver.Chrome()
html = driver.page_source
soup = BeautifulSoup(html, 'html.parser')

# %%
# 리뷰를 추출해주는 함수
def extract_review():
    # 리뷰 추출
    rev = []  # 추출한 리뷰 저장
    driver.find_element(By.XPATH, '//*[@id="app-root"]/div/div/div/div[6]/div[3]/div[3]/div[2]/div/a').send_keys(Keys.ENTER)
    time.sleep(0.5)
    driver.find_element(By.XPATH, '//*[@id="app-root"]/div/div/div/div[6]/div[3]/div[3]/div[2]/div/a').send_keys(Keys.ENTER)
    time.sleep(0.5)
    for i in range(1, 31): # 더보기 눌러놓고 30개 가져오기
        try:  # 사진 있는 후기는 div 3번째에 텍스트 위치
            driver.find_element(By.XPATH, '//*[@id="app-root"]/div/div/div/div[6]/div[3]/div[3]/div[1]/ul/li['+str(i)+']/div[3]/a').send_keys(Keys.ENTER) # 텍스트 전체 볼 수 있게 클릭
            # print('리뷰가 저장됨')
            time.sleep(0.5)
            comment = driver.find_element(By.XPATH, '//*[@id="app-root"]/div/div/div/div[6]/div[3]/div[3]/div[1]/ul/li['+str(i)+']/div[3]/a/span').text  # 리뷰
            # print('리뷰가 저장됨')
            rev.append(comment)
        except: # 사진 없는 후기는 div 2번째에 텍스트가 위치
            try: # 리뷰에 글이 없는경우에 XPATH가 달라짐으로 try - except 추가
                driver.find_element(By.XPATH, '//*[@id="app-root"]/div/div/div/div[6]/div[3]/div[3]/div[1]/ul/li['+str(i)+']/div[2]/a').send_keys(Keys.ENTER)
                time.sleep(0.5)
                comment = driver.find_element(By.XPATH, '//*[@id="app-root"]/div/div/div/div[6]/div[3]/div[3]/div[1]/ul/li['+str(i)+']/div[2]/a/span').text  # 리뷰
                # print('리뷰가 저장됨')
                rev.append(comment)
            except:
                # print('이상한 리뷰임')
                rev.append(pd.NA)

    # print('더 이상 리뷰가 없음')
    return rev

# %%
count = 1 # 성공한 크롤링 카운트
failedCount = 1 # 실패한 크롤링 카운트

crawlingReviewData = [] # 식당 리뷰를 저장할 리스트
crawlingImageData = [] # 식당 이미지를 저장할 리스트
crawlingCategoryData = [] # 식당 업종분류를 저장할 리스트
crawlingVisitCountData = [] # 식당 방문자리뷰 수를 저장할 리스트
crawlingBlogCountData = [] # 식당 블로그리뷰 수를 저장할 리스트
crawlingRatingData = [] # 식당 평점을 저장할 리스트
# crawlingTimeData = [] # 식당 운영시간을 저장할 리스트

result_df = pd.DataFrame()
# len(scrapy_df)
for i in range(len(scrapy_df)):
    url = f"https://map.naver.com/v5/search/{scrapy_df['사업장명'][i]} {scrapy_df['도로명전체주소'][i]}"
    # url = f"https://map.naver.com/v5/search/숙성도 노형본관"
    # url = f"https://map.naver.com/v5/search/가시림 카페 제주 서귀포시 표선면 녹산로 5번길 171"
    driver.get(url)
    time.sleep(2)
    #app-root > div > div > div > div:nth-child(5) > div > div:nth-child(2) > div.place_section_content > div > div.O8qbU.pSavy > div > a > div:nth-child(2) > div > span.A_cdD > div
    #app-root > div > div > div > div:nth-child(5) > div > div:nth-child(2) > div.place_section_content > div > div.O8qbU.pSavy > div > a > div:nth-child(2)
    try:
        driver.switch_to.frame(driver.find_element(By.XPATH, '//*[@id="entryIframe"]')) # iframe 이동
        time.sleep(2)
        html = driver.page_source
        soup = BeautifulSoup(html, 'html.parser')

        # 이미지 3장 뽑아서 저장하기
        images = []  # 이미지 링크를 저장할 리스트
        for i in range(1, 4):
            image_element = soup.select_one(f"#ibu_{i}")  # ibu_1 ~ 3 이런식으로 이미지의 id가 갯수별로 형성됨
            if not image_element:
                continue  # 이미지 요소가 없으면 for 루프 종료
            style = image_element["style"]
            background_image = style.split("url(")[1].split(")")[0]
            images.append(background_image)  # 이미지 링크를 리스트에 추가

        # 음식 카테고리 뽑기 (버튼이라서 CSS_SELECTOR를 써야함)
        foodCategory = driver.find_element(By.CSS_SELECTOR, '#_title > div > span.DJJvD').text

        # # 식당 운영시간 뽑기
        # toggleButton = driver.find_element(By.CSS_SELECTOR, ".O8qbU.pSavy a") # 토글버튼 지정
        # toggleButton.click()
        # time.sleep(1)
        # print("dfdsfsd")
        
        # # timeText = soup.select(".A_cdD")
        # # 요일에 대한 정보 추출
        # everyday_info = soup.find('span', class_='i8cJw').get_text(strip=True)

        # # 영업 시간에 대한 정보 추출
        # business_hours_info = soup.find('div', class_='H3ua4').get_text(strip=True)

        # print("매일 정보:", everyday_info)
        # print("영업 시간 정보:", business_hours_info)
        # time.sleep(0.5)
        # print(timeText)
        


        # 리뷰 탭을 선택하기 전에 버튼 갯수 파악하기 (별점 4.7, 방문자리뷰 100, 블로그리뷰 120) 이런식으로 된곳
        lists = soup.select('.PXMot')  # 버튼들의 class = PXMot
        
        if len(lists) > 2: # (별점이 있는 경우) 별점/방문자리뷰/블로그리뷰 순일때 방문자리뷰는 두번째에 위치=span[2]
            # 별점 수, 리뷰 수 긁어오기
            ratingText = soup.select_one('.PXMot.LXIwF').text # 별점의 class = .PXMot.LXIwF
            visitText = driver.find_element(By.CSS_SELECTOR, '#app-root > div > div > div > div.place_section.no_margin.OP4V8 > div.zD5Nm.undefined > div.dAsGb > span:nth-child(2) > a').text
            blogText = driver.find_element(By.CSS_SELECTOR, '#app-root > div > div > div > div.place_section.no_margin.OP4V8 > div.zD5Nm.undefined > div.dAsGb > span:nth-child(3) > a').text
            
            driver.find_element(By.XPATH, '//*[@id="app-root"]/div/div/div/div[2]/div[1]/div[2]/span[2]/a').send_keys(Keys.ENTER) # 방문자 리뷰
            time.sleep(1)
        
        else: # (별점이 없는 경우) 방문자리뷰/블로그리뷰 순일때 방문자리뷰는 첫번째에 위치=span[1]
            # 리뷰 수 긁어오기
            visitText = driver.find_element(By.CSS_SELECTOR, '#app-root > div > div > div > div.place_section.no_margin.OP4V8 > div.zD5Nm.undefined > div.dAsGb > span:nth-child(1) > a').text
            blogText = driver.find_element(By.CSS_SELECTOR, '#app-root > div > div > div > div.place_section.no_margin.OP4V8 > div.zD5Nm.undefined > div.dAsGb > span:nth-child(2) > a').text

            driver.find_element(By.XPATH, '//*[@id="app-root"]/div/div/div/div[2]/div[1]/div[2]/span[1]/a').send_keys(Keys.ENTER) # 방문자 리뷰 클릭
            time.sleep(1)

        driver.find_element(By.XPATH, '//*[@id="app-root"]/div/div/div/div[6]/div[3]/div[3]/div[1]/div[2]/div[1]/span[2]/a').send_keys(Keys.ENTER) # 최신순으로 클릭
        time.sleep(0.5)
        review = extract_review() # 리뷰 추출 함수 호출
        print(f'현재까지 성공한 크롤링 갯수: {count}')
        crawlingReviewData.append(review)
        crawlingImageData.append(images)
        crawlingCategoryData.append(foodCategory)
        crawlingRatingData.append(ratingText.replace("별점", ""))
        crawlingVisitCountData.append(visitText.split()[-1])
        crawlingBlogCountData.append(blogText.split()[-1])
        count += 1
        ## 별점이 있고 없고에 따라 공백 데이터 추가해주는거 필요
    except:
        crawlingReviewData.append('x')
        crawlingImageData.append('x')
        crawlingCategoryData.append('x')
        crawlingRatingData.append('x')
        crawlingVisitCountData.append("x")
        crawlingBlogCountData.append("x")
        print(f'현재까지 실패한 크롤링 갯수: {failedCount}')
        failedCount += 1


    result_df = pd.DataFrame({'foodCategory': crawlingCategoryData, 'images': crawlingImageData, 'rating': crawlingRatingData, 'visitReviewCount': crawlingVisitCountData, 'blogReviewCount': crawlingBlogCountData,'review': crawlingReviewData})
# Out:
# 현재까지 실패한 크롤링 갯수: 1
# 현재까지 성공한 크롤링 갯수: 1
# 현재까지 성공한 크롤링 갯수: 2
# 현재까지 실패한 크롤링 갯수: 2
# 현재까지 성공한 크롤링 갯수: 3
# 현재까지 실패한 크롤링 갯수: 3
# 현재까지 실패한 크롤링 갯수: 4
# 현재까지 성공한 크롤링 갯수: 4
# 현재까지 성공한 크롤링 갯수: 5
# 현재까지 성공한 크롤링 갯수: 6
# 현재까지 성공한 크롤링 갯수: 7
# 현재까지 성공한 크롤링 갯수: 8
# 현재까지 성공한 크롤링 갯수: 9
# 현재까지 실패한 크롤링 갯수: 5
# 현재까지 실패한 크롤링 갯수: 6
# 현재까지 실패한 크롤링 갯수: 7
# 현재까지 성공한 크롤링 갯수: 10
# 현재까지 성공한 크롤링 갯수: 11
# 현재까지 성공한 크롤링 갯수: 12
# 현재까지 성공한 크롤링 갯수: 13
# 현재까지 성공한 크롤링 갯수: 14
# 현재까지 성공한 크롤링 갯수: 15
# 현재까지 실패한 크롤링 갯수: 8
# 현재까지 성공한 크롤링 갯수: 16
# 현재까지 성공한 크롤링 갯수: 17
# 현재까지 실패한 크롤링 갯수: 9
# 현재까지 성공한 크롤링 갯수: 18
# 현재까지 실패한 크롤링 갯수: 10
# 현재까지 실패한 크롤링 갯수: 11
# 현재까지 성공한 크롤링 갯수: 19
# 현재까지 성공한 크롤링 갯수: 20
# 현재까지 실패한 크롤링 갯수: 12
# 현재까지 실패한 크롤링 갯수: 13
# 현재까지 성공한 크롤링 갯수: 21
# 현재까지 성공한 크롤링 갯수: 22
# 현재까지 실패한 크롤링 갯수: 14
# 현재까지 성공한 크롤링 갯수: 23
# 현재까지 실패한 크롤링 갯수: 15
# 현재까지 성공한 크롤링 갯수: 24
# 현재까지 성공한 크롤링 갯수: 25
# 현재까지 성공한 크롤링 갯수: 26
# 현재까지 실패한 크롤링 갯수: 16
# 현재까지 실패한 크롤링 갯수: 17
# 현재까지 성공한 크롤링 갯수: 27
# 현재까지 실패한 크롤링 갯수: 18
# 현재까지 성공한 크롤링 갯수: 28
# 현재까지 성공한 크롤링 갯수: 29
# 현재까지 성공한 크롤링 갯수: 30
# 현재까지 성공한 크롤링 갯수: 31
# 현재까지 실패한 크롤링 갯수: 19
# 현재까지 실패한 크롤링 갯수: 20
# 현재까지 성공한 크롤링 갯수: 32
# 현재까지 실패한 크롤링 갯수: 21
# 현재까지 성공한 크롤링 갯수: 33
# 현재까지 실패한 크롤링 갯수: 22
# 현재까지 성공한 크롤링 갯수: 34
# 현재까지 실패한 크롤링 갯수: 23
# 현재까지 성공한 크롤링 갯수: 35
# 현재까지 실패한 크롤링 갯수: 24
# 현재까지 실패한 크롤링 갯수: 25
# 현재까지 실패한 크롤링 갯수: 26
# 현재까지 실패한 크롤링 갯수: 27
# 현재까지 성공한 크롤링 갯수: 36
# 현재까지 성공한 크롤링 갯수: 37
# 현재까지 실패한 크롤링 갯수: 28
# 현재까지 성공한 크롤링 갯수: 38
# 현재까지 실패한 크롤링 갯수: 29
# 현재까지 실패한 크롤링 갯수: 30
# 현재까지 실패한 크롤링 갯수: 31
# 현재까지 성공한 크롤링 갯수: 39
# 현재까지 성공한 크롤링 갯수: 40
# 현재까지 실패한 크롤링 갯수: 32
# 현재까지 성공한 크롤링 갯수: 41
# 현재까지 성공한 크롤링 갯수: 42
# 현재까지 성공한 크롤링 갯수: 43
# 현재까지 성공한 크롤링 갯수: 44
# 현재까지 실패한 크롤링 갯수: 33
# 현재까지 성공한 크롤링 갯수: 45
# 현재까지 성공한 크롤링 갯수: 46
# 현재까지 실패한 크롤링 갯수: 34
# 현재까지 실패한 크롤링 갯수: 35
# 현재까지 실패한 크롤링 갯수: 36
# 현재까지 실패한 크롤링 갯수: 37
# 현재까지 실패한 크롤링 갯수: 38
# 현재까지 성공한 크롤링 갯수: 47
# 현재까지 성공한 크롤링 갯수: 48
# 현재까지 성공한 크롤링 갯수: 49
# 현재까지 실패한 크롤링 갯수: 39
# 현재까지 실패한 크롤링 갯수: 40
# 현재까지 성공한 크롤링 갯수: 50
# 현재까지 성공한 크롤링 갯수: 51
# 현재까지 성공한 크롤링 갯수: 52
# 현재까지 실패한 크롤링 갯수: 41
# 현재까지 성공한 크롤링 갯수: 53
# 현재까지 실패한 크롤링 갯수: 42
# 현재까지 성공한 크롤링 갯수: 54
# 현재까지 성공한 크롤링 갯수: 55
# 현재까지 실패한 크롤링 갯수: 43
# 현재까지 성공한 크롤링 갯수: 56
# 현재까지 성공한 크롤링 갯수: 57
# 현재까지 실패한 크롤링 갯수: 44
# 현재까지 성공한 크롤링 갯수: 58
# 현재까지 성공한 크롤링 갯수: 59
# 현재까지 실패한 크롤링 갯수: 45
# 현재까지 성공한 크롤링 갯수: 60
# 현재까지 실패한 크롤링 갯수: 46
# 현재까지 성공한 크롤링 갯수: 61
# 현재까지 실패한 크롤링 갯수: 47
# 현재까지 실패한 크롤링 갯수: 48
# 현재까지 실패한 크롤링 갯수: 49
# 현재까지 실패한 크롤링 갯수: 50
# 현재까지 성공한 크롤링 갯수: 62
# 현재까지 실패한 크롤링 갯수: 51
# 현재까지 실패한 크롤링 갯수: 52
# 현재까지 성공한 크롤링 갯수: 63
# 현재까지 실패한 크롤링 갯수: 53
# 현재까지 실패한 크롤링 갯수: 54
# 현재까지 성공한 크롤링 갯수: 64
# 현재까지 성공한 크롤링 갯수: 65
# 현재까지 실패한 크롤링 갯수: 55
# 현재까지 성공한 크롤링 갯수: 66
# 현재까지 실패한 크롤링 갯수: 56
# 현재까지 실패한 크롤링 갯수: 57
# 현재까지 성공한 크롤링 갯수: 67
# 현재까지 성공한 크롤링 갯수: 68
# 현재까지 실패한 크롤링 갯수: 58
# 현재까지 성공한 크롤링 갯수: 69
# 현재까지 성공한 크롤링 갯수: 70
# 현재까지 실패한 크롤링 갯수: 59
# 현재까지 실패한 크롤링 갯수: 60
# 현재까지 성공한 크롤링 갯수: 71
# 현재까지 성공한 크롤링 갯수: 72
# 현재까지 실패한 크롤링 갯수: 61
# 현재까지 성공한 크롤링 갯수: 73
# 현재까지 성공한 크롤링 갯수: 74
# 현재까지 실패한 크롤링 갯수: 62
# 현재까지 실패한 크롤링 갯수: 63
# 현재까지 실패한 크롤링 갯수: 64
# 현재까지 성공한 크롤링 갯수: 75
# 현재까지 성공한 크롤링 갯수: 76
# 현재까지 실패한 크롤링 갯수: 65
# 현재까지 성공한 크롤링 갯수: 77
# 현재까지 실패한 크롤링 갯수: 66
# 현재까지 실패한 크롤링 갯수: 67
# 현재까지 성공한 크롤링 갯수: 78
# 현재까지 실패한 크롤링 갯수: 68
# 현재까지 실패한 크롤링 갯수: 69
# 현재까지 실패한 크롤링 갯수: 70
# 현재까지 성공한 크롤링 갯수: 79
# 현재까지 실패한 크롤링 갯수: 71
# 현재까지 실패한 크롤링 갯수: 72
# 현재까지 실패한 크롤링 갯수: 73
# 현재까지 실패한 크롤링 갯수: 74
# 현재까지 실패한 크롤링 갯수: 75
# 현재까지 성공한 크롤링 갯수: 80
# 현재까지 성공한 크롤링 갯수: 81
# 현재까지 실패한 크롤링 갯수: 76
# 현재까지 성공한 크롤링 갯수: 82
# 현재까지 성공한 크롤링 갯수: 83
# 현재까지 성공한 크롤링 갯수: 84
# 현재까지 성공한 크롤링 갯수: 85
# 현재까지 실패한 크롤링 갯수: 77
# 현재까지 실패한 크롤링 갯수: 78
# 현재까지 실패한 크롤링 갯수: 79
# 현재까지 실패한 크롤링 갯수: 80
# 현재까지 실패한 크롤링 갯수: 81
# 현재까지 실패한 크롤링 갯수: 82
# 현재까지 실패한 크롤링 갯수: 83
# 현재까지 실패한 크롤링 갯수: 84
# 현재까지 실패한 크롤링 갯수: 85
# 현재까지 실패한 크롤링 갯수: 86
# 현재까지 실패한 크롤링 갯수: 87
# 현재까지 실패한 크롤링 갯수: 88
# 현재까지 실패한 크롤링 갯수: 89
# 현재까지 성공한 크롤링 갯수: 86
# 현재까지 실패한 크롤링 갯수: 90
# 현재까지 실패한 크롤링 갯수: 91
# 현재까지 실패한 크롤링 갯수: 92
# 현재까지 실패한 크롤링 갯수: 93
# 현재까지 실패한 크롤링 갯수: 94
# 현재까지 실패한 크롤링 갯수: 95
# 현재까지 실패한 크롤링 갯수: 96
# 현재까지 실패한 크롤링 갯수: 97
# 현재까지 실패한 크롤링 갯수: 98
# 현재까지 실패한 크롤링 갯수: 99
# 현재까지 실패한 크롤링 갯수: 100
# 현재까지 성공한 크롤링 갯수: 87
# 현재까지 실패한 크롤링 갯수: 101
# 현재까지 성공한 크롤링 갯수: 88
# 현재까지 실패한 크롤링 갯수: 102
# 현재까지 성공한 크롤링 갯수: 89
# 현재까지 실패한 크롤링 갯수: 103
# 현재까지 성공한 크롤링 갯수: 90
# 현재까지 실패한 크롤링 갯수: 104
# 현재까지 성공한 크롤링 갯수: 91
# 현재까지 실패한 크롤링 갯수: 105
# 현재까지 성공한 크롤링 갯수: 92
# 현재까지 성공한 크롤링 갯수: 122
# 현재까지 성공한 크롤링 갯수: 123
# 현재까지 실패한 크롤링 갯수: 145
# 현재까지 실패한 크롤링 갯수: 146
# 현재까지 실패한 크롤링 갯수: 147
# 현재까지 실패한 크롤링 갯수: 148
# 현재까지 성공한 크롤링 갯수: 124
# 현재까지 실패한 크롤링 갯수: 149
# 현재까지 실패한 크롤링 갯수: 150
# 현재까지 성공한 크롤링 갯수: 125
# 현재까지 실패한 크롤링 갯수: 151
# 현재까지 실패한 크롤링 갯수: 152
# 현재까지 성공한 크롤링 갯수: 126
# 현재까지 성공한 크롤링 갯수: 127
# 현재까지 성공한 크롤링 갯수: 128
# 현재까지 성공한 크롤링 갯수: 129
# 현재까지 실패한 크롤링 갯수: 153
# 현재까지 실패한 크롤링 갯수: 154
# 현재까지 성공한 크롤링 갯수: 130
# 현재까지 실패한 크롤링 갯수: 155
# 현재까지 실패한 크롤링 갯수: 156
# 현재까지 성공한 크롤링 갯수: 131
# 현재까지 실패한 크롤링 갯수: 157
# 현재까지 성공한 크롤링 갯수: 132
# 현재까지 실패한 크롤링 갯수: 158
# 현재까지 실패한 크롤링 갯수: 159
# 현재까지 실패한 크롤링 갯수: 160
# 현재까지 실패한 크롤링 갯수: 161
# 현재까지 성공한 크롤링 갯수: 133
# 현재까지 성공한 크롤링 갯수: 134
# 현재까지 실패한 크롤링 갯수: 162
# 현재까지 실패한 크롤링 갯수: 163
# 현재까지 성공한 크롤링 갯수: 135
# 현재까지 성공한 크롤링 갯수: 136
# 현재까지 실패한 크롤링 갯수: 164
# 현재까지 실패한 크롤링 갯수: 165
# 현재까지 실패한 크롤링 갯수: 166
# 현재까지 실패한 크롤링 갯수: 167
# 현재까지 실패한 크롤링 갯수: 168
# 현재까지 실패한 크롤링 갯수: 169
# 현재까지 실패한 크롤링 갯수: 170
# 현재까지 실패한 크롤링 갯수: 171
# 현재까지 실패한 크롤링 갯수: 172
# 현재까지 실패한 크롤링 갯수: 173
# 현재까지 실패한 크롤링 갯수: 174
# 현재까지 성공한 크롤링 갯수: 137
# 현재까지 실패한 크롤링 갯수: 175
# 현재까지 성공한 크롤링 갯수: 138
# 현재까지 성공한 크롤링 갯수: 139
# 현재까지 성공한 크롤링 갯수: 140
# 현재까지 실패한 크롤링 갯수: 176
# 현재까지 실패한 크롤링 갯수: 177
# 현재까지 성공한 크롤링 갯수: 141
# 현재까지 성공한 크롤링 갯수: 142
# 현재까지 실패한 크롤링 갯수: 178
# 현재까지 실패한 크롤링 갯수: 179
# 현재까지 실패한 크롤링 갯수: 180
# 현재까지 성공한 크롤링 갯수: 143
# 현재까지 실패한 크롤링 갯수: 181
# 현재까지 실패한 크롤링 갯수: 182
# 현재까지 실패한 크롤링 갯수: 183
# 현재까지 실패한 크롤링 갯수: 184
# 현재까지 실패한 크롤링 갯수: 185
# 현재까지 실패한 크롤링 갯수: 186
# 현재까지 실패한 크롤링 갯수: 187
# 현재까지 성공한 크롤링 갯수: 144
# 현재까지 성공한 크롤링 갯수: 145
# 현재까지 실패한 크롤링 갯수: 188
# 현재까지 성공한 크롤링 갯수: 373
# 현재까지 실패한 크롤링 갯수: 506
# 현재까지 실패한 크롤링 갯수: 507
# 현재까지 성공한 크롤링 갯수: 374
# 현재까지 실패한 크롤링 갯수: 508
# 현재까지 성공한 크롤링 갯수: 375
# 현재까지 성공한 크롤링 갯수: 376
# 현재까지 실패한 크롤링 갯수: 509
# 현재까지 실패한 크롤링 갯수: 510
# 현재까지 실패한 크롤링 갯수: 511
# 현재까지 실패한 크롤링 갯수: 512
# 현재까지 성공한 크롤링 갯수: 377
# 현재까지 실패한 크롤링 갯수: 513
# 현재까지 실패한 크롤링 갯수: 514
# 현재까지 성공한 크롤링 갯수: 378
# 현재까지 실패한 크롤링 갯수: 515
# 현재까지 실패한 크롤링 갯수: 516
# 현재까지 실패한 크롤링 갯수: 517
# 현재까지 실패한 크롤링 갯수: 518
# 현재까지 실패한 크롤링 갯수: 519
# 현재까지 실패한 크롤링 갯수: 520
# 현재까지 성공한 크롤링 갯수: 379
# 현재까지 실패한 크롤링 갯수: 521
# 현재까지 실패한 크롤링 갯수: 522
# 현재까지 실패한 크롤링 갯수: 523
# 현재까지 성공한 크롤링 갯수: 380
# 현재까지 실패한 크롤링 갯수: 524
# 현재까지 성공한 크롤링 갯수: 381
# 현재까지 실패한 크롤링 갯수: 525
# 현재까지 실패한 크롤링 갯수: 526
# 현재까지 실패한 크롤링 갯수: 527
# 현재까지 실패한 크롤링 갯수: 528
# 현재까지 실패한 크롤링 갯수: 529
# 현재까지 실패한 크롤링 갯수: 530
# 현재까지 성공한 크롤링 갯수: 382
# 현재까지 성공한 크롤링 갯수: 383
# 현재까지 성공한 크롤링 갯수: 384
# 현재까지 실패한 크롤링 갯수: 531
# 현재까지 실패한 크롤링 갯수: 532
# 현재까지 성공한 크롤링 갯수: 385
# 현재까지 실패한 크롤링 갯수: 533
# 현재까지 성공한 크롤링 갯수: 386
# 현재까지 실패한 크롤링 갯수: 534
# 현재까지 성공한 크롤링 갯수: 387
# 현재까지 실패한 크롤링 갯수: 535
# 현재까지 실패한 크롤링 갯수: 536
# 현재까지 실패한 크롤링 갯수: 537
# 현재까지 실패한 크롤링 갯수: 538
# 현재까지 성공한 크롤링 갯수: 388
# 현재까지 실패한 크롤링 갯수: 539
# 현재까지 실패한 크롤링 갯수: 540
# 현재까지 성공한 크롤링 갯수: 389
# 현재까지 성공한 크롤링 갯수: 390
# 현재까지 성공한 크롤링 갯수: 391
# 현재까지 실패한 크롤링 갯수: 541
# 현재까지 성공한 크롤링 갯수: 392
# 현재까지 성공한 크롤링 갯수: 393
# 현재까지 성공한 크롤링 갯수: 394
# 현재까지 성공한 크롤링 갯수: 395
# 현재까지 실패한 크롤링 갯수: 542
# 현재까지 실패한 크롤링 갯수: 543
# 현재까지 실패한 크롤링 갯수: 544
# 현재까지 성공한 크롤링 갯수: 396
# 현재까지 실패한 크롤링 갯수: 545
# 현재까지 성공한 크롤링 갯수: 397
# 현재까지 성공한 크롤링 갯수: 398
# 현재까지 성공한 크롤링 갯수: 399
# 현재까지 성공한 크롤링 갯수: 400
# 현재까지 실패한 크롤링 갯수: 546
# 현재까지 실패한 크롤링 갯수: 547
# 현재까지 실패한 크롤링 갯수: 548
# 현재까지 실패한 크롤링 갯수: 549
# 현재까지 실패한 크롤링 갯수: 550
# 현재까지 실패한 크롤링 갯수: 551
# 현재까지 실패한 크롤링 갯수: 552
# 현재까지 실패한 크롤링 갯수: 553
# 현재까지 실패한 크롤링 갯수: 554
# 현재까지 실패한 크롤링 갯수: 555
# 현재까지 실패한 크롤링 갯수: 556
# 현재까지 실패한 크롤링 갯수: 557
# 현재까지 실패한 크롤링 갯수: 558
# 현재까지 실패한 크롤링 갯수: 559
# 현재까지 실패한 크롤링 갯수: 560
# 현재까지 성공한 크롤링 갯수: 401
# 현재까지 실패한 크롤링 갯수: 561
# 현재까지 성공한 크롤링 갯수: 402
# 현재까지 실패한 크롤링 갯수: 562
# 현재까지 성공한 크롤링 갯수: 403
# 현재까지 성공한 크롤링 갯수: 404
# 현재까지 실패한 크롤링 갯수: 563
# 현재까지 성공한 크롤링 갯수: 405
# 현재까지 성공한 크롤링 갯수: 406
# 현재까지 실패한 크롤링 갯수: 564
# 현재까지 실패한 크롤링 갯수: 565
# 현재까지 성공한 크롤링 갯수: 407
# 현재까지 실패한 크롤링 갯수: 566
# 현재까지 실패한 크롤링 갯수: 567
# 현재까지 실패한 크롤링 갯수: 568
# 현재까지 실패한 크롤링 갯수: 569
# 현재까지 실패한 크롤링 갯수: 570
# 현재까지 실패한 크롤링 갯수: 571
# 현재까지 성공한 크롤링 갯수: 408
# 현재까지 실패한 크롤링 갯수: 572
# 현재까지 성공한 크롤링 갯수: 409
# 현재까지 실패한 크롤링 갯수: 573
# 현재까지 성공한 크롤링 갯수: 410
# 현재까지 실패한 크롤링 갯수: 574
# 현재까지 실패한 크롤링 갯수: 575
# 현재까지 성공한 크롤링 갯수: 411
# 현재까지 성공한 크롤링 갯수: 412
# 현재까지 실패한 크롤링 갯수: 576
# 현재까지 성공한 크롤링 갯수: 413
# 현재까지 실패한 크롤링 갯수: 577
# 현재까지 실패한 크롤링 갯수: 578
# 현재까지 실패한 크롤링 갯수: 579
# 현재까지 성공한 크롤링 갯수: 414
# 현재까지 성공한 크롤링 갯수: 415
# 현재까지 성공한 크롤링 갯수: 416
# 현재까지 실패한 크롤링 갯수: 580
# 현재까지 실패한 크롤링 갯수: 581
# 현재까지 성공한 크롤링 갯수: 417
# 현재까지 성공한 크롤링 갯수: 418
# 현재까지 실패한 크롤링 갯수: 582
# 현재까지 실패한 크롤링 갯수: 583
# 현재까지 성공한 크롤링 갯수: 419
# 현재까지 실패한 크롤링 갯수: 584
# 현재까지 성공한 크롤링 갯수: 420
# 현재까지 실패한 크롤링 갯수: 585
# 현재까지 실패한 크롤링 갯수: 586
# 현재까지 성공한 크롤링 갯수: 421
# 현재까지 실패한 크롤링 갯수: 587
# 현재까지 실패한 크롤링 갯수: 588
# 현재까지 실패한 크롤링 갯수: 589
# 현재까지 실패한 크롤링 갯수: 590
# 현재까지 실패한 크롤링 갯수: 591
# 현재까지 성공한 크롤링 갯수: 422
# 현재까지 실패한 크롤링 갯수: 592
# 현재까지 실패한 크롤링 갯수: 593
# 현재까지 성공한 크롤링 갯수: 423
# 현재까지 실패한 크롤링 갯수: 594
# 현재까지 실패한 크롤링 갯수: 595
# 현재까지 실패한 크롤링 갯수: 596
# 현재까지 실패한 크롤링 갯수: 597
# 현재까지 성공한 크롤링 갯수: 424
# 현재까지 실패한 크롤링 갯수: 598
# 현재까지 실패한 크롤링 갯수: 599
# 현재까지 실패한 크롤링 갯수: 600
# 현재까지 성공한 크롤링 갯수: 425
# 현재까지 실패한 크롤링 갯수: 601
# 현재까지 실패한 크롤링 갯수: 602
# 현재까지 성공한 크롤링 갯수: 426
# 현재까지 성공한 크롤링 갯수: 427
# 현재까지 실패한 크롤링 갯수: 603
# 현재까지 성공한 크롤링 갯수: 428
# 현재까지 실패한 크롤링 갯수: 604
# 현재까지 실패한 크롤링 갯수: 605
# 현재까지 실패한 크롤링 갯수: 606
# 현재까지 성공한 크롤링 갯수: 429
# 현재까지 성공한 크롤링 갯수: 430
# 현재까지 실패한 크롤링 갯수: 607
# 현재까지 성공한 크롤링 갯수: 431
# 현재까지 실패한 크롤링 갯수: 608
# 현재까지 성공한 크롤링 갯수: 432
# 현재까지 실패한 크롤링 갯수: 609
# 현재까지 성공한 크롤링 갯수: 433
# 현재까지 성공한 크롤링 갯수: 434
# 현재까지 성공한 크롤링 갯수: 435
# 현재까지 실패한 크롤링 갯수: 610
# 현재까지 실패한 크롤링 갯수: 611
# 현재까지 실패한 크롤링 갯수: 612
# 현재까지 실패한 크롤링 갯수: 613
# 현재까지 성공한 크롤링 갯수: 436
# 현재까지 성공한 크롤링 갯수: 437
# 현재까지 실패한 크롤링 갯수: 614
# 현재까지 실패한 크롤링 갯수: 615
# 현재까지 성공한 크롤링 갯수: 438
# 현재까지 성공한 크롤링 갯수: 439
# 현재까지 실패한 크롤링 갯수: 616
# 현재까지 실패한 크롤링 갯수: 617
# 현재까지 성공한 크롤링 갯수: 440
# 현재까지 성공한 크롤링 갯수: 441
# 현재까지 실패한 크롤링 갯수: 618
# 현재까지 실패한 크롤링 갯수: 619
# 현재까지 실패한 크롤링 갯수: 620
# 현재까지 실패한 크롤링 갯수: 621
# 현재까지 성공한 크롤링 갯수: 442
# 현재까지 성공한 크롤링 갯수: 443
# 현재까지 성공한 크롤링 갯수: 444
# 현재까지 성공한 크롤링 갯수: 445
# 현재까지 성공한 크롤링 갯수: 446
# 현재까지 실패한 크롤링 갯수: 622
# 현재까지 실패한 크롤링 갯수: 623
# 현재까지 실패한 크롤링 갯수: 624
# 현재까지 실패한 크롤링 갯수: 625
# 현재까지 성공한 크롤링 갯수: 447
# 현재까지 실패한 크롤링 갯수: 626
# 현재까지 실패한 크롤링 갯수: 627
# 현재까지 실패한 크롤링 갯수: 628
# 현재까지 실패한 크롤링 갯수: 629
# 현재까지 성공한 크롤링 갯수: 448
# 현재까지 실패한 크롤링 갯수: 630
# 현재까지 실패한 크롤링 갯수: 631
# 현재까지 실패한 크롤링 갯수: 632
# 현재까지 실패한 크롤링 갯수: 633
# 현재까지 성공한 크롤링 갯수: 449
# 현재까지 실패한 크롤링 갯수: 634
# 현재까지 실패한 크롤링 갯수: 635
# 현재까지 실패한 크롤링 갯수: 636
# 현재까지 성공한 크롤링 갯수: 450
# 현재까지 실패한 크롤링 갯수: 637
# 현재까지 성공한 크롤링 갯수: 451
# 현재까지 실패한 크롤링 갯수: 638
# 현재까지 실패한 크롤링 갯수: 639
# 현재까지 실패한 크롤링 갯수: 640
# 현재까지 성공한 크롤링 갯수: 452
# 현재까지 실패한 크롤링 갯수: 641
# 현재까지 실패한 크롤링 갯수: 642
# 현재까지 실패한 크롤링 갯수: 643
# 현재까지 실패한 크롤링 갯수: 644
# 현재까지 성공한 크롤링 갯수: 453
# 현재까지 실패한 크롤링 갯수: 645
# 현재까지 성공한 크롤링 갯수: 454
# 현재까지 성공한 크롤링 갯수: 455
# 현재까지 성공한 크롤링 갯수: 456
# 현재까지 실패한 크롤링 갯수: 646
# 현재까지 실패한 크롤링 갯수: 647
# 현재까지 성공한 크롤링 갯수: 457
# 현재까지 성공한 크롤링 갯수: 458
# 현재까지 성공한 크롤링 갯수: 459
# 현재까지 실패한 크롤링 갯수: 648
# 현재까지 실패한 크롤링 갯수: 649
# 현재까지 실패한 크롤링 갯수: 650
# 현재까지 성공한 크롤링 갯수: 460
# 현재까지 실패한 크롤링 갯수: 651
# 현재까지 실패한 크롤링 갯수: 652
# 현재까지 실패한 크롤링 갯수: 653
# 현재까지 실패한 크롤링 갯수: 654
# 현재까지 실패한 크롤링 갯수: 655
# 현재까지 실패한 크롤링 갯수: 656
# 현재까지 성공한 크롤링 갯수: 461
# 현재까지 성공한 크롤링 갯수: 462
# 현재까지 실패한 크롤링 갯수: 657
# 현재까지 성공한 크롤링 갯수: 463
# 현재까지 성공한 크롤링 갯수: 464
# 현재까지 실패한 크롤링 갯수: 658
# 현재까지 성공한 크롤링 갯수: 465
# 현재까지 실패한 크롤링 갯수: 659
# 현재까지 성공한 크롤링 갯수: 466
# 현재까지 실패한 크롤링 갯수: 660
# 현재까지 실패한 크롤링 갯수: 661
# 현재까지 성공한 크롤링 갯수: 467
# 현재까지 실패한 크롤링 갯수: 662
# 현재까지 실패한 크롤링 갯수: 663
# 현재까지 실패한 크롤링 갯수: 664
# 현재까지 실패한 크롤링 갯수: 665
# 현재까지 실패한 크롤링 갯수: 666
# 현재까지 실패한 크롤링 갯수: 667
# 현재까지 성공한 크롤링 갯수: 468
# 현재까지 성공한 크롤링 갯수: 469
# 현재까지 실패한 크롤링 갯수: 668
# 현재까지 실패한 크롤링 갯수: 669
# 현재까지 실패한 크롤링 갯수: 670
# 현재까지 실패한 크롤링 갯수: 671
# 현재까지 실패한 크롤링 갯수: 672
# 현재까지 성공한 크롤링 갯수: 470
# 현재까지 성공한 크롤링 갯수: 471
# 현재까지 성공한 크롤링 갯수: 472
# 현재까지 성공한 크롤링 갯수: 473
# 현재까지 실패한 크롤링 갯수: 673
# 현재까지 실패한 크롤링 갯수: 674
# 현재까지 실패한 크롤링 갯수: 675
# 현재까지 실패한 크롤링 갯수: 676
# 현재까지 성공한 크롤링 갯수: 474
# 현재까지 성공한 크롤링 갯수: 475
# 현재까지 성공한 크롤링 갯수: 476
# 현재까지 실패한 크롤링 갯수: 677
# 현재까지 성공한 크롤링 갯수: 477
# 현재까지 성공한 크롤링 갯수: 478
# 현재까지 성공한 크롤링 갯수: 479
# 현재까지 실패한 크롤링 갯수: 678
# 현재까지 성공한 크롤링 갯수: 480
# 현재까지 실패한 크롤링 갯수: 679
# 현재까지 실패한 크롤링 갯수: 680
# 현재까지 실패한 크롤링 갯수: 681
# 현재까지 실패한 크롤링 갯수: 682
# 현재까지 실패한 크롤링 갯수: 683
# 현재까지 실패한 크롤링 갯수: 684
# 현재까지 실패한 크롤링 갯수: 685
# 현재까지 실패한 크롤링 갯수: 686
# 현재까지 실패한 크롤링 갯수: 687
# 현재까지 성공한 크롤링 갯수: 481
# 현재까지 성공한 크롤링 갯수: 482
# 현재까지 실패한 크롤링 갯수: 688
# 현재까지 실패한 크롤링 갯수: 689
# 현재까지 실패한 크롤링 갯수: 690
# 현재까지 성공한 크롤링 갯수: 483
# 현재까지 성공한 크롤링 갯수: 484
# 현재까지 성공한 크롤링 갯수: 485
# 현재까지 실패한 크롤링 갯수: 691
# 현재까지 성공한 크롤링 갯수: 486
# 현재까지 실패한 크롤링 갯수: 692
# 현재까지 성공한 크롤링 갯수: 487
# 현재까지 성공한 크롤링 갯수: 488
# 현재까지 실패한 크롤링 갯수: 693
# 현재까지 실패한 크롤링 갯수: 694
# 현재까지 성공한 크롤링 갯수: 489
# 현재까지 실패한 크롤링 갯수: 695
# 현재까지 성공한 크롤링 갯수: 490
# 현재까지 성공한 크롤링 갯수: 491
# 현재까지 성공한 크롤링 갯수: 492
# 현재까지 성공한 크롤링 갯수: 493
# 현재까지 실패한 크롤링 갯수: 696
# 현재까지 실패한 크롤링 갯수: 697
# 현재까지 성공한 크롤링 갯수: 494
# 현재까지 실패한 크롤링 갯수: 698
# 현재까지 실패한 크롤링 갯수: 699
# 현재까지 실패한 크롤링 갯수: 700
# 현재까지 실패한 크롤링 갯수: 701
# 현재까지 성공한 크롤링 갯수: 495
# 현재까지 성공한 크롤링 갯수: 496
# 현재까지 실패한 크롤링 갯수: 702
# 현재까지 성공한 크롤링 갯수: 497
# 현재까지 실패한 크롤링 갯수: 703
# 현재까지 성공한 크롤링 갯수: 498
# 현재까지 성공한 크롤링 갯수: 499
# 현재까지 성공한 크롤링 갯수: 500
# 현재까지 실패한 크롤링 갯수: 704
# 현재까지 성공한 크롤링 갯수: 501
# 현재까지 실패한 크롤링 갯수: 705
# 현재까지 성공한 크롤링 갯수: 502
# 현재까지 실패한 크롤링 갯수: 706
# 현재까지 성공한 크롤링 갯수: 503
# 현재까지 성공한 크롤링 갯수: 504
# 현재까지 성공한 크롤링 갯수: 505
# 현재까지 성공한 크롤링 갯수: 506
# 현재까지 성공한 크롤링 갯수: 507
# 현재까지 실패한 크롤링 갯수: 707
# 현재까지 실패한 크롤링 갯수: 708
# 현재까지 성공한 크롤링 갯수: 508
# 현재까지 실패한 크롤링 갯수: 709
# 현재까지 성공한 크롤링 갯수: 509
# 현재까지 실패한 크롤링 갯수: 710
# 현재까지 실패한 크롤링 갯수: 711
# 현재까지 실패한 크롤링 갯수: 712
# 현재까지 실패한 크롤링 갯수: 713
# 현재까지 실패한 크롤링 갯수: 714
# 현재까지 실패한 크롤링 갯수: 715
# 현재까지 실패한 크롤링 갯수: 716
# 현재까지 성공한 크롤링 갯수: 510
# 현재까지 성공한 크롤링 갯수: 511
# 현재까지 실패한 크롤링 갯수: 717
# 현재까지 실패한 크롤링 갯수: 718
# 현재까지 성공한 크롤링 갯수: 512
# 현재까지 성공한 크롤링 갯수: 513
# 현재까지 실패한 크롤링 갯수: 719
# 현재까지 성공한 크롤링 갯수: 514
# 현재까지 실패한 크롤링 갯수: 720
# 현재까지 성공한 크롤링 갯수: 515
# 현재까지 성공한 크롤링 갯수: 516
# 현재까지 실패한 크롤링 갯수: 721
# 현재까지 실패한 크롤링 갯수: 722
# 현재까지 실패한 크롤링 갯수: 723
# 현재까지 실패한 크롤링 갯수: 724
# 현재까지 성공한 크롤링 갯수: 517
# 현재까지 실패한 크롤링 갯수: 725
# 현재까지 실패한 크롤링 갯수: 726
# 현재까지 실패한 크롤링 갯수: 727
# 현재까지 실패한 크롤링 갯수: 728
# 현재까지 실패한 크롤링 갯수: 729
# 현재까지 실패한 크롤링 갯수: 730
# 현재까지 실패한 크롤링 갯수: 731
# 현재까지 성공한 크롤링 갯수: 518
# 현재까지 성공한 크롤링 갯수: 519
# 현재까지 실패한 크롤링 갯수: 732
# 현재까지 성공한 크롤링 갯수: 520
# 현재까지 실패한 크롤링 갯수: 733
# 현재까지 실패한 크롤링 갯수: 734
# 현재까지 실패한 크롤링 갯수: 735
# 현재까지 실패한 크롤링 갯수: 736
# 현재까지 실패한 크롤링 갯수: 737
# 현재까지 실패한 크롤링 갯수: 738
# 현재까지 실패한 크롤링 갯수: 739
# 현재까지 실패한 크롤링 갯수: 740
# 현재까지 실패한 크롤링 갯수: 741
# 현재까지 성공한 크롤링 갯수: 521
# 현재까지 성공한 크롤링 갯수: 522
# 현재까지 성공한 크롤링 갯수: 523
# 현재까지 실패한 크롤링 갯수: 742
# 현재까지 성공한 크롤링 갯수: 524
# 현재까지 실패한 크롤링 갯수: 743
# 현재까지 실패한 크롤링 갯수: 744
# 현재까지 성공한 크롤링 갯수: 525
# 현재까지 실패한 크롤링 갯수: 745
# 현재까지 성공한 크롤링 갯수: 526
# 현재까지 성공한 크롤링 갯수: 527
# 현재까지 성공한 크롤링 갯수: 528
# 현재까지 실패한 크롤링 갯수: 746
# 현재까지 성공한 크롤링 갯수: 529
# 현재까지 성공한 크롤링 갯수: 530
# 현재까지 실패한 크롤링 갯수: 747
# 현재까지 실패한 크롤링 갯수: 748
# 현재까지 실패한 크롤링 갯수: 749
# 현재까지 실패한 크롤링 갯수: 750
# 현재까지 실패한 크롤링 갯수: 751
# 현재까지 실패한 크롤링 갯수: 752
# 현재까지 실패한 크롤링 갯수: 753
# 현재까지 성공한 크롤링 갯수: 531
# 현재까지 실패한 크롤링 갯수: 754
# 현재까지 성공한 크롤링 갯수: 532
# 현재까지 실패한 크롤링 갯수: 755
# 현재까지 실패한 크롤링 갯수: 756
# 현재까지 실패한 크롤링 갯수: 757
# 현재까지 실패한 크롤링 갯수: 758
# 현재까지 실패한 크롤링 갯수: 759
# 현재까지 실패한 크롤링 갯수: 760
# 현재까지 성공한 크롤링 갯수: 533
# 현재까지 성공한 크롤링 갯수: 534
# 현재까지 실패한 크롤링 갯수: 761
# 현재까지 성공한 크롤링 갯수: 535
# 현재까지 성공한 크롤링 갯수: 536
# 현재까지 실패한 크롤링 갯수: 762
# 현재까지 실패한 크롤링 갯수: 763
# 현재까지 실패한 크롤링 갯수: 764
# 현재까지 실패한 크롤링 갯수: 765
# 현재까지 성공한 크롤링 갯수: 537
# 현재까지 실패한 크롤링 갯수: 766
# 현재까지 실패한 크롤링 갯수: 767
# 현재까지 실패한 크롤링 갯수: 768
# 현재까지 실패한 크롤링 갯수: 769
# 현재까지 실패한 크롤링 갯수: 770
# 현재까지 실패한 크롤링 갯수: 771
# 현재까지 성공한 크롤링 갯수: 538
# 현재까지 성공한 크롤링 갯수: 539
# 현재까지 실패한 크롤링 갯수: 772
# 현재까지 실패한 크롤링 갯수: 773
# 현재까지 실패한 크롤링 갯수: 774
# 현재까지 실패한 크롤링 갯수: 775
# 현재까지 성공한 크롤링 갯수: 540
# 현재까지 성공한 크롤링 갯수: 541
# 현재까지 실패한 크롤링 갯수: 776
# 현재까지 성공한 크롤링 갯수: 542
# 현재까지 성공한 크롤링 갯수: 543
# 현재까지 실패한 크롤링 갯수: 777
# 현재까지 실패한 크롤링 갯수: 778
# 현재까지 실패한 크롤링 갯수: 779
# 현재까지 실패한 크롤링 갯수: 780
# 현재까지 실패한 크롤링 갯수: 781
# 현재까지 실패한 크롤링 갯수: 782
# 현재까지 성공한 크롤링 갯수: 544
# 현재까지 실패한 크롤링 갯수: 783
# 현재까지 실패한 크롤링 갯수: 784
# 현재까지 성공한 크롤링 갯수: 545
# 현재까지 실패한 크롤링 갯수: 785
# 현재까지 실패한 크롤링 갯수: 786
# 현재까지 실패한 크롤링 갯수: 787
# 현재까지 실패한 크롤링 갯수: 788
# 현재까지 성공한 크롤링 갯수: 546
# 현재까지 성공한 크롤링 갯수: 547
# 현재까지 성공한 크롤링 갯수: 548
# 현재까지 실패한 크롤링 갯수: 789
# 현재까지 성공한 크롤링 갯수: 549
# 현재까지 실패한 크롤링 갯수: 790
# 현재까지 성공한 크롤링 갯수: 550
# 현재까지 실패한 크롤링 갯수: 791
# 현재까지 실패한 크롤링 갯수: 792
# 현재까지 성공한 크롤링 갯수: 551
# 현재까지 성공한 크롤링 갯수: 552
# 현재까지 실패한 크롤링 갯수: 793
# 현재까지 성공한 크롤링 갯수: 553
# 현재까지 실패한 크롤링 갯수: 794
# 현재까지 성공한 크롤링 갯수: 554
# 현재까지 성공한 크롤링 갯수: 555
# 현재까지 성공한 크롤링 갯수: 556
# 현재까지 실패한 크롤링 갯수: 795
# 현재까지 실패한 크롤링 갯수: 796
# 현재까지 실패한 크롤링 갯수: 797
# 현재까지 성공한 크롤링 갯수: 557
# 현재까지 실패한 크롤링 갯수: 798
# 현재까지 실패한 크롤링 갯수: 799
# 현재까지 성공한 크롤링 갯수: 558
# 현재까지 성공한 크롤링 갯수: 559
# 현재까지 성공한 크롤링 갯수: 560
# 현재까지 성공한 크롤링 갯수: 561
# 현재까지 실패한 크롤링 갯수: 800
# 현재까지 실패한 크롤링 갯수: 801
# 현재까지 성공한 크롤링 갯수: 562
# 현재까지 실패한 크롤링 갯수: 802
# 현재까지 실패한 크롤링 갯수: 803
# 현재까지 실패한 크롤링 갯수: 804
# 현재까지 실패한 크롤링 갯수: 805
# 현재까지 실패한 크롤링 갯수: 806
# 현재까지 실패한 크롤링 갯수: 807
# 현재까지 실패한 크롤링 갯수: 808
# 현재까지 성공한 크롤링 갯수: 563
# 현재까지 실패한 크롤링 갯수: 809
# 현재까지 실패한 크롤링 갯수: 810
# 현재까지 실패한 크롤링 갯수: 811
# 현재까지 성공한 크롤링 갯수: 564
# 현재까지 실패한 크롤링 갯수: 812
# 현재까지 실패한 크롤링 갯수: 813
# 현재까지 성공한 크롤링 갯수: 565
# 현재까지 실패한 크롤링 갯수: 814
# 현재까지 실패한 크롤링 갯수: 815
# 현재까지 성공한 크롤링 갯수: 566
# 현재까지 실패한 크롤링 갯수: 816
# 현재까지 성공한 크롤링 갯수: 567
# 현재까지 성공한 크롤링 갯수: 568
# 현재까지 실패한 크롤링 갯수: 817
# 현재까지 실패한 크롤링 갯수: 818
# 현재까지 실패한 크롤링 갯수: 819
# 현재까지 실패한 크롤링 갯수: 820
# 현재까지 실패한 크롤링 갯수: 821
# 현재까지 성공한 크롤링 갯수: 569
# 현재까지 실패한 크롤링 갯수: 822
# 현재까지 실패한 크롤링 갯수: 823
# 현재까지 성공한 크롤링 갯수: 570
# 현재까지 성공한 크롤링 갯수: 571
# 현재까지 성공한 크롤링 갯수: 572
# 현재까지 성공한 크롤링 갯수: 573
# 현재까지 성공한 크롤링 갯수: 574
# 현재까지 성공한 크롤링 갯수: 575
# 현재까지 실패한 크롤링 갯수: 824
# 현재까지 실패한 크롤링 갯수: 825
# 현재까지 성공한 크롤링 갯수: 576
# 현재까지 성공한 크롤링 갯수: 577
# 현재까지 성공한 크롤링 갯수: 578
# 현재까지 실패한 크롤링 갯수: 826
# 현재까지 실패한 크롤링 갯수: 827
# 현재까지 실패한 크롤링 갯수: 828
# 현재까지 실패한 크롤링 갯수: 829
# 현재까지 실패한 크롤링 갯수: 830
# 현재까지 성공한 크롤링 갯수: 579
# 현재까지 실패한 크롤링 갯수: 831
# 현재까지 성공한 크롤링 갯수: 580
# 현재까지 성공한 크롤링 갯수: 581
# 현재까지 실패한 크롤링 갯수: 832
# 현재까지 실패한 크롤링 갯수: 833
# 현재까지 실패한 크롤링 갯수: 834
# 현재까지 실패한 크롤링 갯수: 835
# 현재까지 실패한 크롤링 갯수: 836
# 현재까지 실패한 크롤링 갯수: 837
# 현재까지 실패한 크롤링 갯수: 838
# 현재까지 성공한 크롤링 갯수: 582
# 현재까지 성공한 크롤링 갯수: 583
# 현재까지 실패한 크롤링 갯수: 839
# 현재까지 실패한 크롤링 갯수: 840
# 현재까지 실패한 크롤링 갯수: 841
# 현재까지 실패한 크롤링 갯수: 842
# 현재까지 성공한 크롤링 갯수: 584
# 현재까지 실패한 크롤링 갯수: 843
# 현재까지 성공한 크롤링 갯수: 585
# 현재까지 실패한 크롤링 갯수: 844
# 현재까지 성공한 크롤링 갯수: 586
# 현재까지 실패한 크롤링 갯수: 845
# 현재까지 실패한 크롤링 갯수: 846
# 현재까지 실패한 크롤링 갯수: 847
# 현재까지 성공한 크롤링 갯수: 587
# 현재까지 성공한 크롤링 갯수: 588
# 현재까지 실패한 크롤링 갯수: 848
# 현재까지 성공한 크롤링 갯수: 589
# 현재까지 성공한 크롤링 갯수: 590
# 현재까지 실패한 크롤링 갯수: 849
# 현재까지 실패한 크롤링 갯수: 850
# 현재까지 성공한 크롤링 갯수: 591
# 현재까지 실패한 크롤링 갯수: 851
# 현재까지 실패한 크롤링 갯수: 852
# 현재까지 실패한 크롤링 갯수: 853
# 현재까지 성공한 크롤링 갯수: 592
# 현재까지 실패한 크롤링 갯수: 854
# 현재까지 성공한 크롤링 갯수: 593
# 현재까지 실패한 크롤링 갯수: 855
# 현재까지 실패한 크롤링 갯수: 856
# 현재까지 성공한 크롤링 갯수: 594
# 현재까지 실패한 크롤링 갯수: 857
# 현재까지 실패한 크롤링 갯수: 858
# 현재까지 성공한 크롤링 갯수: 595
# 현재까지 실패한 크롤링 갯수: 859
# 현재까지 실패한 크롤링 갯수: 860
# 현재까지 성공한 크롤링 갯수: 596
# 현재까지 성공한 크롤링 갯수: 597
# 현재까지 실패한 크롤링 갯수: 861
# 현재까지 실패한 크롤링 갯수: 862
# 현재까지 성공한 크롤링 갯수: 598
# 현재까지 실패한 크롤링 갯수: 863
# 현재까지 성공한 크롤링 갯수: 599
# 현재까지 성공한 크롤링 갯수: 600
# 현재까지 실패한 크롤링 갯수: 864
# 현재까지 실패한 크롤링 갯수: 865
# 현재까지 실패한 크롤링 갯수: 866
# 현재까지 실패한 크롤링 갯수: 867
# 현재까지 실패한 크롤링 갯수: 868
# 현재까지 실패한 크롤링 갯수: 869
# 현재까지 성공한 크롤링 갯수: 601
# 현재까지 실패한 크롤링 갯수: 870
# 현재까지 성공한 크롤링 갯수: 602
# 현재까지 실패한 크롤링 갯수: 871
# 현재까지 실패한 크롤링 갯수: 872
# 현재까지 성공한 크롤링 갯수: 603
# 현재까지 성공한 크롤링 갯수: 604
# 현재까지 실패한 크롤링 갯수: 873
# 현재까지 실패한 크롤링 갯수: 874
# 현재까지 실패한 크롤링 갯수: 875
# 현재까지 성공한 크롤링 갯수: 605
# 현재까지 실패한 크롤링 갯수: 876
# 현재까지 성공한 크롤링 갯수: 606
# 현재까지 실패한 크롤링 갯수: 877
# 현재까지 성공한 크롤링 갯수: 607
# 현재까지 성공한 크롤링 갯수: 608
# 현재까지 실패한 크롤링 갯수: 878
# 현재까지 실패한 크롤링 갯수: 879
# 현재까지 실패한 크롤링 갯수: 880
# 현재까지 성공한 크롤링 갯수: 609
# 현재까지 성공한 크롤링 갯수: 610
# 현재까지 실패한 크롤링 갯수: 881
# 현재까지 실패한 크롤링 갯수: 882
# 현재까지 성공한 크롤링 갯수: 611
# 현재까지 성공한 크롤링 갯수: 612
# 현재까지 실패한 크롤링 갯수: 883
# 현재까지 성공한 크롤링 갯수: 613
# 현재까지 성공한 크롤링 갯수: 614
# 현재까지 실패한 크롤링 갯수: 884
# 현재까지 성공한 크롤링 갯수: 615
# 현재까지 실패한 크롤링 갯수: 885
# 현재까지 실패한 크롤링 갯수: 886
# 현재까지 성공한 크롤링 갯수: 616
# 현재까지 실패한 크롤링 갯수: 887
# 현재까지 실패한 크롤링 갯수: 888
# 현재까지 성공한 크롤링 갯수: 617
# 현재까지 성공한 크롤링 갯수: 618
# 현재까지 성공한 크롤링 갯수: 619
# 현재까지 성공한 크롤링 갯수: 620
# 현재까지 실패한 크롤링 갯수: 889
# 현재까지 성공한 크롤링 갯수: 621
# 현재까지 실패한 크롤링 갯수: 890
# 현재까지 성공한 크롤링 갯수: 622
# 현재까지 성공한 크롤링 갯수: 623
# 현재까지 실패한 크롤링 갯수: 891
# 현재까지 실패한 크롤링 갯수: 892
# 현재까지 성공한 크롤링 갯수: 624
# 현재까지 실패한 크롤링 갯수: 893
# 현재까지 실패한 크롤링 갯수: 894
# 현재까지 실패한 크롤링 갯수: 895
# 현재까지 성공한 크롤링 갯수: 625
# 현재까지 성공한 크롤링 갯수: 626
# 현재까지 실패한 크롤링 갯수: 896
# 현재까지 실패한 크롤링 갯수: 897
# 현재까지 실패한 크롤링 갯수: 898
# 현재까지 실패한 크롤링 갯수: 899
# 현재까지 성공한 크롤링 갯수: 627
# 현재까지 실패한 크롤링 갯수: 900
# 현재까지 실패한 크롤링 갯수: 901
# 현재까지 성공한 크롤링 갯수: 628
# 현재까지 성공한 크롤링 갯수: 629
# 현재까지 실패한 크롤링 갯수: 902
# 현재까지 성공한 크롤링 갯수: 630
# 현재까지 실패한 크롤링 갯수: 903
# 현재까지 성공한 크롤링 갯수: 631
# 현재까지 실패한 크롤링 갯수: 904
# 현재까지 성공한 크롤링 갯수: 632
# 현재까지 성공한 크롤링 갯수: 633
# 현재까지 성공한 크롤링 갯수: 634
# 현재까지 실패한 크롤링 갯수: 905
# 현재까지 실패한 크롤링 갯수: 906
# 현재까지 성공한 크롤링 갯수: 635
# 현재까지 실패한 크롤링 갯수: 907
# 현재까지 성공한 크롤링 갯수: 636
# 현재까지 실패한 크롤링 갯수: 908
# 현재까지 실패한 크롤링 갯수: 909
# 현재까지 성공한 크롤링 갯수: 637
# 현재까지 실패한 크롤링 갯수: 910
# 현재까지 실패한 크롤링 갯수: 911
# 현재까지 실패한 크롤링 갯수: 912
# 현재까지 성공한 크롤링 갯수: 638
# 현재까지 성공한 크롤링 갯수: 639
# 현재까지 실패한 크롤링 갯수: 913
# 현재까지 성공한 크롤링 갯수: 640
# 현재까지 성공한 크롤링 갯수: 641
# 현재까지 성공한 크롤링 갯수: 642
# 현재까지 실패한 크롤링 갯수: 914
# 현재까지 실패한 크롤링 갯수: 915
# 현재까지 실패한 크롤링 갯수: 916
# 현재까지 성공한 크롤링 갯수: 643
# 현재까지 실패한 크롤링 갯수: 917
# 현재까지 실패한 크롤링 갯수: 918
# 현재까지 성공한 크롤링 갯수: 644
# 현재까지 실패한 크롤링 갯수: 919
# 현재까지 실패한 크롤링 갯수: 920
# 현재까지 성공한 크롤링 갯수: 645
# 현재까지 성공한 크롤링 갯수: 646
# 현재까지 성공한 크롤링 갯수: 647
# 현재까지 성공한 크롤링 갯수: 648
# 현재까지 실패한 크롤링 갯수: 921
# 현재까지 성공한 크롤링 갯수: 649
# 현재까지 실패한 크롤링 갯수: 922
# 현재까지 실패한 크롤링 갯수: 923
# 현재까지 성공한 크롤링 갯수: 650
# 현재까지 실패한 크롤링 갯수: 924
# 현재까지 실패한 크롤링 갯수: 925
# 현재까지 실패한 크롤링 갯수: 926
# 현재까지 성공한 크롤링 갯수: 651
# 현재까지 성공한 크롤링 갯수: 652
# 현재까지 성공한 크롤링 갯수: 653
# 현재까지 실패한 크롤링 갯수: 927
# 현재까지 실패한 크롤링 갯수: 928
# 현재까지 실패한 크롤링 갯수: 929
# 현재까지 실패한 크롤링 갯수: 930
# 현재까지 성공한 크롤링 갯수: 654
# 현재까지 성공한 크롤링 갯수: 655
# 현재까지 성공한 크롤링 갯수: 656
# 현재까지 실패한 크롤링 갯수: 931
# 현재까지 실패한 크롤링 갯수: 932
# 현재까지 실패한 크롤링 갯수: 933
# 현재까지 실패한 크롤링 갯수: 934
# 현재까지 성공한 크롤링 갯수: 657
# 현재까지 실패한 크롤링 갯수: 935
# 현재까지 성공한 크롤링 갯수: 658
# 현재까지 실패한 크롤링 갯수: 936
# 현재까지 성공한 크롤링 갯수: 659
# 현재까지 성공한 크롤링 갯수: 660
# 현재까지 성공한 크롤링 갯수: 661
# 현재까지 성공한 크롤링 갯수: 662
# 현재까지 성공한 크롤링 갯수: 663
# 현재까지 실패한 크롤링 갯수: 937
# 현재까지 성공한 크롤링 갯수: 664
# 현재까지 성공한 크롤링 갯수: 665
# 현재까지 성공한 크롤링 갯수: 666
# 현재까지 성공한 크롤링 갯수: 667
# 현재까지 성공한 크롤링 갯수: 668
# 현재까지 실패한 크롤링 갯수: 938
# 현재까지 실패한 크롤링 갯수: 939
# 현재까지 실패한 크롤링 갯수: 940
# 현재까지 실패한 크롤링 갯수: 941
# 현재까지 실패한 크롤링 갯수: 942
# 현재까지 실패한 크롤링 갯수: 943
# 현재까지 실패한 크롤링 갯수: 944
# 현재까지 실패한 크롤링 갯수: 945
# 현재까지 성공한 크롤링 갯수: 669
# 현재까지 실패한 크롤링 갯수: 946
# 현재까지 실패한 크롤링 갯수: 947
# 현재까지 실패한 크롤링 갯수: 948
# 현재까지 실패한 크롤링 갯수: 949
# 현재까지 성공한 크롤링 갯수: 670
# 현재까지 성공한 크롤링 갯수: 671
# 현재까지 실패한 크롤링 갯수: 950
# 현재까지 성공한 크롤링 갯수: 672
# 현재까지 성공한 크롤링 갯수: 673
# 현재까지 성공한 크롤링 갯수: 674
# 현재까지 성공한 크롤링 갯수: 675
# 현재까지 성공한 크롤링 갯수: 676
# 현재까지 성공한 크롤링 갯수: 677
# 현재까지 실패한 크롤링 갯수: 951
# 현재까지 실패한 크롤링 갯수: 952
# 현재까지 실패한 크롤링 갯수: 953
# 현재까지 실패한 크롤링 갯수: 954
# 현재까지 실패한 크롤링 갯수: 955
# 현재까지 실패한 크롤링 갯수: 956
# 현재까지 실패한 크롤링 갯수: 957
# 현재까지 실패한 크롤링 갯수: 958
# 현재까지 성공한 크롤링 갯수: 678
# 현재까지 실패한 크롤링 갯수: 959
# ---------------------------------------------------------------------------
# NoSuchWindowException                     Traceback (most recent call last)
# Cell In[10], line 18
#      15 url = f"https://map.naver.com/v5/search/{scrapy_df['사업장명'][i]} {scrapy_df['도로명전체주소'][i]}"
#      16 # url = f"https://map.naver.com/v5/search/숙성도 노형본관"
#      17 # url = f"https://map.naver.com/v5/search/가시림 카페 제주 서귀포시 표선면 녹산로 5번길 171"
# ---> 18 driver.get(url)
#      19 time.sleep(2)
#      20 #app-root > div > div > div > div:nth-child(5) > div > div:nth-child(2) > div.place_section_content > div > div.O8qbU.pSavy > div > a > div:nth-child(2) > div > span.A_cdD > div
#      21 #app-root > div > div > div > div:nth-child(5) > div > div:nth-child(2) > div.place_section_content > div > div.O8qbU.pSavy > div > a > div:nth-child(2)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\selenium\webdriver\remote\webdriver.py:356, in WebDriver.get(self, url)
#     354 def get(self, url: str) -> None:
#     355     """Loads a web page in the current browser session."""
# --> 356     self.execute(Command.GET, {"url": url})
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\selenium\webdriver\remote\webdriver.py:347, in WebDriver.execute(self, driver_command, params)
#     345 response = self.command_executor.execute(driver_command, params)
#     346 if response:
# --> 347     self.error_handler.check_response(response)
#     348     response["value"] = self._unwrap_value(response.get("value", None))
#     349     return response
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\selenium\webdriver\remote\errorhandler.py:229, in ErrorHandler.check_response(self, response)
#     227         alert_text = value["alert"].get("text")
#     228     raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 229 raise exception_class(message, screen, stacktrace)
#
# NoSuchWindowException: Message: no such window: target window already closed
# from unknown error: web view not found
#   (Session info: chrome=122.0.6261.94)
# Stacktrace:
# 	GetHandleVerifier [0x00007FF665FEAD22+56930]
# 	(No symbol) [0x00007FF665F5F622]
# 	(No symbol) [0x00007FF665E142E5]
# 	(No symbol) [0x00007FF665DF1D4C]
# 	(No symbol) [0x00007FF665E823F7]
# 	(No symbol) [0x00007FF665E97891]
# 	(No symbol) [0x00007FF665E7BA43]
# 	(No symbol) [0x00007FF665E4D438]
# 	(No symbol) [0x00007FF665E4E4D1]
# 	GetHandleVerifier [0x00007FF666366AAD+3709933]
# 	GetHandleVerifier [0x00007FF6663BFFED+4075821]
# 	GetHandleVerifier [0x00007FF6663B817F+4043455]
# 	GetHandleVerifier [0x00007FF666089756+706710]
# 	(No symbol) [0x00007FF665F6B8FF]
# 	(No symbol) [0x00007FF665F66AE4]
# 	(No symbol) [0x00007FF665F66C3C]
# 	(No symbol) [0x00007FF665F568F4]
# 	BaseThreadInitThunk [0x00007FF9329C7344+20]
# 	RtlUserThreadStart [0x00007FF9340C26B1+33]

# %%
# 출력 옵션 설정 (컬럼 너비 조정)
# pd.set_option('display.max_colwidth', None) # 길이 제한 해제
# pd.set_option('display.max_colwidth', 50) # 길이 기본 값

# %%
result_df.tail()
# Out:
#      foodCategory                                             images rating  \
# 1632            x                                                  x      x
# 1633            x                                                  x      x
# 1634            x                                                  x      x
# 1635      육류,고기요리  ["https://search.pstatic.net/common/?autoRotat...   4.05
# 1636            x                                                  x      x
#
#      visitReviewCount blogReviewCount  \
# 1632                x               x
# 1633                x               x
# 1634                x               x
# 1635              117              27
# 1636                x               x
#
#                                                  review
# 1632                                                  x
# 1633                                                  x
# 1634                                                  x
# 1635  [굉장히 푸짐한 양이라서 배부르게 먹고 남은 고기는 포장해서 왔어요. 갈비를 배부르...
# 1636                                                  x

# %%
result_df.to_csv("Data/제주도식당_테스트크롤링.csv", index=False)
