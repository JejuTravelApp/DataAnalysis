# %% [markdown]
# # 제주도 식당의 리뷰와 정보들을 네이버에서 크롤링해오기
# - 제주도식당_전처리.csv를 사용

# %%
import pandas as pd
import random
import time
import re
import warnings
warnings.filterwarnings('ignore')
from selenium import webdriver  # 동적크롤링
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By
from bs4 import BeautifulSoup

# %% [markdown]
# ### 크롤링에 필요한 데이터 불러오기

# %%
df = pd.read_csv("Data/제주도식당_전처리.csv", index_col=False)

# %%
df.head()
# Out:
#          사업장명 업종구분대분류   업종구분소분류                        소재지전체주소  \
# 0      탑동에이치지   일반음식점        기타        제주특별자치도 제주시 삼도이동 1120-2
# 1    에릭스에스프레소   일반음식점        기타   제주특별자치도 제주시 구좌읍 세화리 1397-6번지
# 2    일품순두부한림점   일반음식점        한식   제주특별자치도 제주시 한림읍 대림리 1845-2번지
# 3  김복남맥주제주아라점   일반음식점  식육(숯불구이)          제주특별자치도 제주시 아라일동 6139
# 4       봉플라봉뱅   일반음식점        기타  제주특별자치도 제주시 연동 312-57번지 정인하우스
#
#                                도로명전체주소         lat          lng
# 0      제주특별자치도 제주시 무근성안길 16, 1층 (삼도이동)  33.5151128  126.5202001
# 1           제주특별자치도 제주시 구좌읍 구좌로 77, 1층  33.5214225  126.8588743
# 2         제주특별자치도 제주시 한림읍 한림상로 237, 1층  33.4192601  126.2674304
# 3   제주특별자치도 제주시 중앙로 581, 에이동 1층 (아라일동)  33.4714278  126.5457848
# 4  제주특별자치도 제주시 문송1길 6-1, 정인하우스 1층 (연동)  33.4879976  126.4978933

# %% [markdown]
# ### 크롤링에 필요한 컬럼만 뽑아서 저장하기

# %%
scrapy_df = df[["사업장명", "도로명전체주소"]]

# %%
scrapy_df.head()
# Out:
#          사업장명                              도로명전체주소
# 0      탑동에이치지      제주특별자치도 제주시 무근성안길 16, 1층 (삼도이동)
# 1    에릭스에스프레소           제주특별자치도 제주시 구좌읍 구좌로 77, 1층
# 2    일품순두부한림점         제주특별자치도 제주시 한림읍 한림상로 237, 1층
# 3  김복남맥주제주아라점   제주특별자치도 제주시 중앙로 581, 에이동 1층 (아라일동)
# 4       봉플라봉뱅  제주특별자치도 제주시 문송1길 6-1, 정인하우스 1층 (연동)

# %% [markdown]
# ### 네이버 지도창에서 검색할 때 정확도를 높이기 위해 도로명 주소의 , 뒤에는 제거
# > 이유는 네이버 지도탭에서 검색시 "사업장명" + "도로명전체주소" 형식으로 검색하면 정확히 원하는 식당이 뜨는 빈도수가 높기 때문에
# 도로명전체주소가 필요한 것인데, 문제는 도로명주소에 상세주소가 적혀있으면 검색이 안될 확률이 높았음
# 때문에 ','뒤에 있는 상세주소를 제거할 필요가 있음

# %%
scrapy_df['도로명전체주소'] = scrapy_df['도로명전체주소'].str.split(',', n=1).str[0]

# %%
scrapy_df.head(40)
# Out:
#           사업장명                         도로명전체주소
# 0       탑동에이치지            제주특별자치도 제주시 무근성안길 16
# 1     에릭스에스프레소          제주특별자치도 제주시 구좌읍 구좌로 77
# 2     일품순두부한림점        제주특별자치도 제주시 한림읍 한림상로 237
# 3   김복남맥주제주아라점             제주특별자치도 제주시 중앙로 581
ver.find_element(By.XPATH, '//*[@id="app-root"]/div/div/div/div[6]/div[3]/div[3]/div[2]/div/a').send_keys(Keys.ENTER)
#         time.sleep(1)
#         driver.find_element(By.XPATH, '//*[@id="app-root"]/div/div/div/div[6]/div[3]/div[3]/div[2]/div/a').send_keys(Keys.ENTER)
#         time.sleep(1)

#     for i in range(1, rangeNum): # 더보기 눌러놓고 30개 가져오기
#         try:  # 사진 있는 후기는 div 3번째에 텍스트 위치
#             driver.find_element(By.XPATH, '//*[@id="app-root"]/div/div/div/div[6]/div[3]/div[3]/div[1]/ul/li['+str(i)+']/div[3]/a').send_keys(Keys.ENTER) # 텍스트 전체 볼 수 있게 클릭
#             # print('리뷰가 저장됨')
#             # time.sleep(0.5)
#             comment = driver.find_element(By.XPATH, '//*[@id="app-root"]/div/div/div/div[6]/div[3]/div[3]/div[1]/ul/li['+str(i)+']/div[3]/a/span').text  # 리뷰
#             # print('리뷰가 저장됨')
#             rev.append(comment)
#         except: # 사진 없는 후기는 div 2번째에 텍스트가 위치
#             try: # 리뷰에 글이 없는경우에 XPATH가 달라짐으로 try - except 추가
#                 driver.find_element(By.XPATH, '//*[@id="app-root"]/div/div/div/div[6]/div[3]/div[3]/div[1]/ul/li['+str(i)+']/div[2]/a').send_keys(Keys.ENTER)
#                 comment = driver.find_element(By.XPATH, '//*[@id="app-root"]/div/div/div/div[6]/div[3]/div[3]/div[1]/ul/li['+str(i)+']/div[2]/a/span').text  # 리뷰
#                 # print('리뷰가 저장됨')
#                 rev.append(comment)
#             except:
#                 # print('이상한 리뷰임')
#                 rev.append(pd.NA)

#     # print('더 이상 리뷰가 없음')
#     return rev

# %% [markdown]
# #### 버튼에있는 방문 리뷰수가 아닌 실제 방문 리뷰수를 가져오는게 불가능해서
# #### for문을 돌려가며 더보기 버튼을 누르는 방식으로 변경

# %%
# # 리뷰를 추출해주는 함수
# def extract_review(listsCount: int):
#     rev = []  # 추출한 리뷰 저장
#     for i in range(1, 11): # 더보기 누르지 않은 상태로 최대 10개
#         # try:  
#             # if listsCount == 1: # 블로그 리뷰가 없을 시에 달라지는 XPATH값 예외처리 추가
#             #     driver.find_element(By.XPATH, f'//*[@id="app-root"]/div/div/div/div[6]/div[2]/div[3]/div[1]/ul/li[{i}]/div[2]/a').send_keys(Keys.ENTER) 
#             #     comment = driver.find_element(By.XPATH, f'//*[@id="app-root"]/div/div/div/div[6]/div[2]/div[3]/div[1]/ul/li[{i}]/div[2]/a/span').text  # 리뷰
#             #     time.sleep(random.uniform(0.2, 0.5))
#             #     rev.append(comment) 
#             # else:
#             #     driver.find_element(By.XPATH, f'//*[@id="app-root"]/div/div/div/div[6]/div[3]/div[3]/div[1]/ul/li[{i}]/div[3]/a').send_keys(Keys.ENTER) 
#             #     comment = driver.find_element(By.XPATH, f'//*[@id="app-root"]/div/div/div/div[6]/div[3]/div[3]/div[1]/ul/li[{i}]/div[3]/a/span').text  # 리뷰
#             #     time.sleep(random.uniform(0.2, 0.5))
#             #     rev.append(comment)

#         #    for i in range(1, 11): # 더보기 누르지 않은 상태로 최대 10개
#             try:  # 사진 있는 후기는 div 3번째에 텍스트 위치
#                 driver.find_element(By.XPATH, '//*[@id="app-root"]/div/div/div/div[6]/div[3]/div[3]/div[1]/ul/li['+str(i)+']/div[3]/a').send_keys(Keys.ENTER) # 텍스트 전체 볼 수 있게 클릭
#                 # print('리뷰가 저장됨')
#                 time.sleep(random.uniform(1,2))
#                 comment = driver.find_element(By.XPATH, '//*[@id="app-root"]/div/div/div/div[6]/div[3]/div[3]/div[1]/ul/li['+str(i)+']/div[3]/a/span').text  # 리뷰
#                 # print('리뷰가 저장됨')
#                 rev.append(comment)
#             except: # 사진 없는 후기는 div 2번째에 텍스트가 위치
#                 try: # 리뷰에 글이 없는경우에 XPATH가 달라짐으로 try - except 추가
#                     driver.find_element(By.XPATH, '//*[@id="app-root"]/div/div/div/div[6]/div[3]/div[3]/div[1]/ul/li['+str(i)+']/div[2]/a').send_keys(Keys.ENTER)
#                     time.sleep(random.uniform(1,2))
#                     comment = driver.find_element(By.XPATH, '//*[@id="app-root"]/div/div/div/div[6]/div[3]/div[3]/div[1]/ul/li['+str(i)+']/div[2]/a/span').text  # 리뷰
#                     # print('리뷰가 저장됨')
#                     rev.append(comment)
#                 except:
#                     # print('이상한 리뷰임')
#                     rev.append("")

#         # except: 
#         #     try: 
#         #         if listsCount == 1: # 블로그 리뷰가 없을 시에 달라지는 XPATH값 예외처리 추가
#         #             driver.find_element(By.XPATH, f'//*[@id="app-root"]/div/div/div/div[6]/div[2]/div[3]/div[1]/ul/li[{i}]/div[2]/a').send_keys(Keys.ENTER) 
#         #             comment = driver.find_element(By.XPATH, f'//*[@id="app-root"]/div/div/div/div[6]/div[2]/div[3]/div[1]/ul/li[{i}]/div[2]/a/span').text  # 리뷰
#         #             time.sleep(random.uniform(0.2, 0.5))
#         #             rev.append(comment)                    
#         #         else:
#         #             driver.find_element(By.XPATH, f'//*[@id="app-root"]/div/div/div/div[6]/div[3]/div[3]/div[1]/ul/li[{i}]/div[3]/a').send_keys(Keys.ENTER) 
#         #             comment = driver.find_element(By.XPATH, f'//*[@id="app-root"]/div/div/div/div[6]/div[3]/div[3]/div[1]/ul/li[{i}]/div[3]/a/span').text  # 리뷰
#         #             time.sleep(random.uniform(0.2, 0.5))
#         #             rev.append(comment)
#         #     except:
#         #         rev.append("")

#     # 더 많은 리뷰가 있는지 확인하고, 있을 경우에는 추가 리뷰를 가져오기 위해 "더보기" 버튼 클릭
#     try:
#         if listsCount == 1:
#             driver.find_element(By.XPATH, '//*[@id="app-root"]/div/div/div/div[6]/div[2]/div[3]/div[2]/div/a').send_keys(Keys.ENTER)
#         else:
#             driver.find_element(By.XPATH, '//*[@id="app-root"]/div/div/div/div[6]/div[3]/div[3]/div[2]/div/a').send_keys(Keys.ENTER)   
#         time.sleep(1)
#         for i in range(11, 21):
#             try:  
#                 if listsCount == 1: # 블로그 리뷰가 없을 시에 달라지는 XPATH값 예외처리 추가
#                     driver.find_element(By.XPATH, f'//*[@id="app-root"]/div/div/div/div[6]/div[2]/div[3]/div[1]/ul/li[{i}]/div[2]/a').send_keys(Keys.ENTER)  
#                     comment = driver.find_element(By.XPATH, f'//*[@id="app-root"]/div/div/div/div[6]/div[2]/div[3]/div/ul/li[{i}]/div[2]/a/span').text  # 리뷰
#                     time.sleep(random.uniform(0.2, 0.5))
#                     rev.append(comment) 
#                 else:
#                     driver.find_element(By.XPATH, f'//*[@id="app-root"]/div/div/div/div[6]/div[3]/div[3]/div[1]/ul/li[{i}]/div[3]/a').send_keys(Keys.ENTER) 
#                     comment = driver.find_element(By.XPATH, f'//*[@id="app-root"]/div/div/div/div[6]/div[3]/div[3]/div[1]/ul/li[{i}]/div[3]/a/span').text  # 리뷰
#                     time.sleep(random.uniform(0.2, 0.5))
#                     rev.append(comment)

#             except: 
#                 try: 
#                     if listsCount == 1: # 블로그 리뷰가 없을 시에 달라지는 XPATH값 예외처리 추가
#                         driver.find_element(By.XPATH, f'//*[@id="app-root"]/div/div/div/div[6]/div[2]/div[3]/div[1]/ul/li[{i}]/div[2]/a').send_keys(Keys.ENTER)  
#                         comment = driver.find_element(By.XPATH, f'//*[@id="app-root"]/div/div/div/div[6]/div[2]/div[3]/div/ul/li[{i}]/div[2]/a/span').text  # 리뷰
#                         time.sleep(random.uniform(0.2, 0.5))
#                         rev.append(comment) 
#                     else:
#                         driver.find_element(By.XPATH, f'//*[@id="app-root"]/div/div/div/div[6]/div[3]/div[3]/div[1]/ul/li[{i}]/div[3]/a').send_keys(Keys.ENTER) 
#                         comment = driver.find_element(By.XPATH, f'//*[@id="app-root"]/div/div/div/div[6]/div[3]/div[3]/div[1]/ul/li[{i}]/div[3]/a/span').text  # 리뷰
#                         time.sleep(random.uniform(0.2, 0.5))
#                         rev.append(comment)

#                 except:
#                     rev.append("")

#     except:
#         print('더 이상 리뷰가 없음')

#     # 추가로 한 번 더 더보기 버튼을 클릭하여 최대 30개의 리뷰 가져오기
#     try:
#         time.sleep(random.uniform(0.3, 0.5)) 
#         if listsCount == 1:
#             driver.find_element(By.XPATH, '//*[@id="app-root"]/div/div/div/div[6]/div[2]/div[3]/div[2]/div/a').send_keys(Keys.ENTER)
#         else:
#             driver.find_element(By.XPATH, '//*[@id="app-root"]/div/div/div/div[6]/div[3]/div[3]/div[2]/div/a').send_keys(Keys.ENTER)   
#         time.sleep(1)
#         for i in range(21, 31):
#             try:  
#                 if listsCount == 1: # 블로그 리뷰가 없을 시에 달라지는 XPATH값 예외처리 추가
#                     driver.find_element(By.XPATH, f'//*[@id="app-root"]/div/div/div/div[6]/div[2]/div[3]/div[1]/ul/li[{i}]/div[2]/a').send_keys(Keys.ENTER)  
#                     comment = driver.find_element(By.XPATH, f'//*[@id="app-root"]/div/div/div/div[6]/div[2]/div[3]/div/ul/li[{i}]/div[2]/a/span').text  # 리뷰
#                     time.sleep(random.uniform(0.2, 0.5))
#                     rev.append(comment) 
#                 else:
#                     driver.find_element(By.XPATH, f'//*[@id="app-root"]/div/div/div/div[6]/div[3]/div[3]/div[1]/ul/li[{i}]/div[3]/a').send_keys(Keys.ENTER) 
#                     comment = driver.find_element(By.XPATH, f'//*[@id="app-root"]/div/div/div/div[6]/div[3]/div[3]/div[1]/ul/li[{i}]/div[3]/a/span').text  # 리뷰
#                     time.sleep(random.uniform(0.2, 0.5))
#                     rev.append(comment)

#             except: 
#                 try: 
#                     if listsCount == 1: # 블로그 리뷰가 없을 시에 달라지는 XPATH값 예외처리 추가
#                         driver.find_element(By.XPATH, f'//*[@id="app-root"]/div/div/div/div[6]/div[2]/div[3]/div[1]/ul/li[{i}]/div[2]/a').send_keys(Keys.ENTER)  
#                         comment = driver.find_element(By.XPATH, f'//*[@id="app-root"]/div/div/div/div[6]/div[2]/div[3]/div/ul/li[{i}]/div[2]/a/span').text  # 리뷰
#                         time.sleep(random.uniform(0.2, 0.5))
#                         rev.append(comment) 
#                     else:
#                         driver.find_element(By.XPATH, f'//*[@id="app-root"]/div/div/div/div[6]/div[3]/div[3]/div[1]/ul/li[{i}]/div[3]/a').send_keys(Keys.ENTER) 
#                         comment = driver.find_element(By.XPATH, f'//*[@id="app-root"]/div/div/div/div[6]/div[3]/div[3]/div[1]/ul/li[{i}]/div[3]/a/span').text  # 리뷰
#                         time.sleep(random.uniform(0.2, 0.5))
#                         rev.append(comment)

#                 except:
#                     rev.append("")

#     except:
#         print('더 이상 리뷰가 없음')

#     return rev

# %%
# 리뷰를 추출해주는 함수
def extract_review(listsCount: int):
    time.sleep(random.uniform(3, 3.5))
    rev = []  # 추출한 리뷰 저장
    for i in range(1, 11): 
        try:  # 사진 있는 후기는 div 3번째에 텍스트 위치
            if listsCount == 1: # 리뷰버튼 갯수가 1개면 태그가 6331이아닌 6231로됨 
                driver.find_element(By.XPATH, '//*[@id="app-root"]/div/div/div/div[6]/div[2]/div[3]/div[1]/ul/li['+str(i)+']/div[3]/a').send_keys(Keys.ENTER) # 텍스트 전체 볼 수 있게 클릭
                time.sleep(0.1)
                comment = driver.find_element(By.XPATH, '//*[@id="app-root"]/div/div/div/div[6]/div[2]/div[3]/div[1]/ul/li['+str(i)+']/div[3]/a/span').text  # 리뷰

                rev.append(comment)
            else:
                driver.find_element(By.XPATH, '//*[@id="app-root"]/div/div/div/div[6]/div[3]/div[3]/div[1]/ul/li['+str(i)+']/div[3]/a').send_keys(Keys.ENTER) # 텍스트 전체 볼 수 있게 클릭
                time.sleep(0.1)
                comment = driver.find_element(By.XPATH, '//*[@id="app-root"]/div/div/div/div[6]/div[3]/div[3]/div[1]/ul/li['+str(i)+']/div[3]/a/span').text  # 리뷰

                rev.append(comment)
        except: # 사진 없는 후기는 div 2번째에 텍스트가 위치
            try: # 리뷰에 글이 없는경우에 XPATH가 달라짐으로 try - except 추가
                if listsCount == 1: # 리뷰버튼 갯수가 1개면 태그가 6331이아닌 6231로됨 
                    driver.find_element(By.XPATH, '//*[@id="app-root"]/div/div/div/div[6]/div[2]/div[3]/div[1]/ul/li['+str(i)+']/div[2]/a').send_keys(Keys.ENTER)
                    time.sleep(0.1)
                    comment = driver.find_element(By.XPATH, '//*[@id="app-root"]/div/div/div/div[6]/div[2]/div[3]/div[1]/ul/li['+str(i)+']/div[2]/a/span').text  # 리뷰
                    
                    rev.append(comment)
                else:
                    driver.find_element(By.XPATH, '//*[@id="app-root"]/div/div/div/div[6]/div[3]/div[3]/div[1]/ul/li['+str(i)+']/div[2]/a').send_keys(Keys.ENTER)
                    time.sleep(0.1)
                    comment = driver.find_element(By.XPATH, '//*[@id="app-root"]/div/div/div/div[6]/div[3]/div[3]/div[1]/ul/li['+str(i)+']/div[2]/a/span').text  # 리뷰
                    
                    rev.append(comment)
            except:
                rev.append("")

    # 더 많은 리뷰가 있는지 확인하고, 있을 경우에는 추가 리뷰를 가져오기 위해 "더보기" 버튼 클릭
    try:
        if listsCount == 1:
            driver.find_element(By.XPATH, '//*[@id="app-root"]/div/div/div/div[6]/div[2]/div[3]/div[2]/div/a').send_keys(Keys.ENTER)
        else:
            driver.find_element(By.XPATH, '//*[@id="app-root"]/div/div/div/div[6]/div[3]/div[3]/div[2]/div/a').send_keys(Keys.ENTER)   
        time.sleep(0.5)
        for i in range(11, 21):
            try:  # 사진 있는 후기는 div 3번째에 텍스트 위치
                if listsCount == 1: # 리뷰버튼 갯수가 1개면 태그가 6331이아닌 6231로됨 
                    driver.find_element(By.XPATH, '//*[@id="app-root"]/div/div/div/div[6]/div[2]/div[3]/div[1]/ul/li['+str(i)+']/div[3]/a').send_keys(Keys.ENTER) # 텍스트 전체 볼 수 있게 클릭
                    time.sleep(0.1)
                    comment = driver.find_element(By.XPATH, '//*[@id="app-root"]/div/div/div/div[6]/div[2]/div[3]/div[1]/ul/li['+str(i)+']/div[3]/a/span').text  # 리뷰

                    rev.append(comment)
                else:
                    driver.find_element(By.XPATH, '//*[@id="app-root"]/div/div/div/div[6]/div[3]/div[3]/div[1]/ul/li['+str(i)+']/div[3]/a').send_keys(Keys.ENTER) # 텍스트 전체 볼 수 있게 클릭
                    time.sleep(0.1)
                    comment = driver.find_element(By.XPATH, '//*[@id="app-root"]/div/div/div/div[6]/div[3]/div[3]/div[1]/ul/li['+str(i)+']/div[3]/a/span').text  # 리뷰

                    rev.append(comment)
            except: # 사진 없는 후기는 div 2번째에 텍스트가 위치
                try: # 리뷰에 글이 없는경우에 XPATH가 달라짐으로 try - except 추가
                    if listsCount == 1: # 리뷰버튼 갯수가 1개면 태그가 6331이아닌 6231로됨 
                        driver.find_element(By.XPATH, '//*[@id="app-root"]/div/div/div/div[6]/div[2]/div[3]/div[1]/ul/li['+str(i)+']/div[2]/a').send_keys(Keys.ENTER)
                        time.sleep(0.1)
                        comment = driver.find_element(By.XPATH, '//*[@id="app-root"]/div/div/div/div[6]/div[2]/div[3]/div[1]/ul/li['+str(i)+']/div[2]/a/span').text  # 리뷰
                        
                        rev.append(comment)
                    else:
                        driver.find_element(By.XPATH, '//*[@id="app-root"]/div/div/div/div[6]/div[3]/div[3]/div[1]/ul/li['+str(i)+']/div[2]/a').send_keys(Keys.ENTER)
                        time.sleep(0.1)
                        comment = driver.find_element(By.XPATH, '//*[@id="app-root"]/div/div/div/div[6]/div[3]/div[3]/div[1]/ul/li['+str(i)+']/div[2]/a/span').text  # 리뷰
                        
                        rev.append(comment)
                except:
                    rev.append("")

    except:
        print('더 이상 리뷰가 없음')
    
    try:
        if listsCount == 1:
            driver.find_element(By.XPATH, '//*[@id="app-root"]/div/div/div/div[6]/div[2]/div[3]/div[2]/div/a').send_keys(Keys.ENTER)
        else:
            driver.find_element(By.XPATH, '//*[@id="app-root"]/div/div/div/div[6]/div[3]/div[3]/div[2]/div/a').send_keys(Keys.ENTER)   
        time.sleep(0.5)
        for i in range(21, 31):
            try:  # 사진 있는 후기는 div 3번째에 텍스트 위치
                if listsCount == 1: # 리뷰버튼 갯수가 1개면 태그가 6331이아닌 6231로됨 
                    driver.find_element(By.XPATH, '//*[@id="app-root"]/div/div/div/div[6]/div[2]/div[3]/div[1]/ul/li['+str(i)+']/div[3]/a').send_keys(Keys.ENTER) # 텍스트 전체 볼 수 있게 클릭
                    time.sleep(0.1)
                    comment = driver.find_element(By.XPATH, '//*[@id="app-root"]/div/div/div/div[6]/div[2]/div[3]/div[1]/ul/li['+str(i)+']/div[3]/a/span').text  # 리뷰

                    rev.append(comment)
                else:
                    driver.find_element(By.XPATH, '//*[@id="app-root"]/div/div/div/div[6]/div[3]/div[3]/div[1]/ul/li['+str(i)+']/div[3]/a').send_keys(Keys.ENTER) # 텍스트 전체 볼 수 있게 클릭
                    time.sleep(0.1)
                    comment = driver.find_element(By.XPATH, '//*[@id="app-root"]/div/div/div/div[6]/div[3]/div[3]/div[1]/ul/li['+str(i)+']/div[3]/a/span').text  # 리뷰

                    rev.append(comment)
            except: # 사진 없는 후기는 div 2번째에 텍스트가 위치
                try: # 리뷰에 글이 없는경우에 XPATH가 달라짐으로 try - except 추가
                    if listsCount == 1: # 리뷰버튼 갯수가 1개면 태그가 6331이아닌 6231로됨 
                        driver.find_element(By.XPATH, '//*[@id="app-root"]/div/div/div/div[6]/div[2]/div[3]/div[1]/ul/li['+str(i)+']/div[2]/a').send_keys(Keys.ENTER)
                        time.sleep(0.1)
                        comment = driver.find_element(By.XPATH, '//*[@id="app-root"]/div/div/div/div[6]/div[2]/div[3]/div[1]/ul/li['+str(i)+']/div[2]/a/span').text  # 리뷰
                        
                        rev.append(comment)
                    else:
                        driver.find_element(By.XPATH, '//*[@id="app-root"]/div/div/div/div[6]/div[3]/div[3]/div[1]/ul/li['+str(i)+']/div[2]/a').send_keys(Keys.ENTER)
                        time.sleep(0.1)
                        comment = driver.find_element(By.XPATH, '//*[@id="app-root"]/div/div/div/div[6]/div[3]/div[3]/div[1]/ul/li['+str(i)+']/div[2]/a/span').text  # 리뷰
                        
                        rev.append(comment)

                except:
                    rev.append("")

    except:
        print('더 이상 리뷰가 없음')
    
    
    return rev

# %%
count = 0 # 성공한 크롤링 카운트
failedCount = 0 # 실패한 크롤링 카운트

crawlingReviewData = [] # 식당 리뷰를 저장할 리스트
crawlingImageData = [] # 식당 이미지를 저장할 리스트
crawlingCategoryData = [] # 식당 업종분류를 저장할 리스트
crawlingVisitCountData = [] # 식당 방문자리뷰 수를 저장할 리스트
crawlingBlogCountData = [] # 식당 블로그리뷰 수를 저장할 리스트
crawlingRatingData = [] # 식당 평점을 저장할 리스트
errorResult = ""

result_df = pd.DataFrame()
# range(len(scrapy_df))
# range(1, 2)
for i in range(2001, 3001):
    url = f"https://map.naver.com/v5/search/{scrapy_df['사업장명'][i]} {scrapy_df['도로명전체주소'][i]}"
    # url = f"https://map.naver.com/v5/search/걸작떡볶이제주노형점 제주특별자치도 제주시 노형9길 7"
    # url = f"https://map.naver.com/v5/search/신촌도시락 제주 제주시 조천읍 신북로 88"
    # url = f"https://map.naver.com/v5/search/가시림 카페 제주 서귀포시 표선면 녹산로 5번길 171"
    
    driver.get(url)
    time.sleep(random.uniform(2.0, 2.5))
    try: 
        driver.switch_to.frame(driver.find_element(By.XPATH, '//*[@id="entryIframe"]')) # iframe 이동
        time.sleep(random.uniform(1.5, 2.0))
        html = driver.page_source
        soup = BeautifulSoup(html, 'html.parser')

        # 이미지 3장 뽑아서 저장하기
        images = []  # 이미지 링크를 저장할 리스트
        for i in range(1, 4):
            image_element = soup.select_one(f"#ibu_{i}")  # ibu_1 ~ 3 이런식으로 이미지의 id가 갯수별로 형성됨
            if not image_element:
                continue  # 이미지 요소가 없으면 for 루프 종료
            style = image_element["style"]
            background_image = style.split("url(")[1].split(")")[0]
            images.append(background_image)  # 이미지 링크를 리스트에 추가

        # 음식 카테고리 뽑기 (버튼이라서 CSS_SELECTOR를 써야함)
        foodCategory = driver.find_element(By.CSS_SELECTOR, '#_title > div > span.DJJvD').text


        # 리뷰 탭을 선택하기 전에 버튼 갯수 파악하기 (별점 4.7, 방문자리뷰 100, 블로그리뷰 120) 이런식으로 된곳
        lists = soup.select('.PXMot')  # 버튼들의 class = PXMot
        errorResult = "검색 결과 없음"
        if len(lists) == 3: # (별점이 있는 경우) 별점/방문자리뷰/블로그리뷰 순일때 방문자리뷰는 두번째에 위치=span[2]
            # 별점 수, 리뷰 수 긁어오기
            ratingText = soup.select_one('.PXMot.LXIwF').text # 별점의 class = .PXMot.LXIwF
            visitText = driver.find_element(By.CSS_SELECTOR, '#app-root > div > div > div > div.place_section.no_margin.OP4V8 > div.zD5Nm.undefined > div.dAsGb > span:nth-child(2) > a').text
            blogText = driver.find_element(By.CSS_SELECTOR, '#app-root > div > div > div > div.place_section.no_margin.OP4V8 > div.zD5Nm.undefined > div.dAsGb > span:nth-child(3) > a').text

            driver.find_element(By.XPATH, '//*[@id="app-root"]/div/div/div/div[2]/div[1]/div[2]/span[2]/a').send_keys(Keys.ENTER) # 방문자 리뷰
            time.sleep(1)
            driver.find_element(By.XPATH, '//*[@id="app-root"]/div/div/div/div[6]/div[3]/div[3]/div[1]/div[2]/div[1]/span[2]/a').send_keys(Keys.ENTER) # 최신순으로 클릭
            time.sleep(1)
        elif len(lists) == 2: # (별점이 없는 경우) 방문자리뷰/블로그리뷰 순일때 방문자리뷰는 첫번째에 위치=span[1]
            # 리뷰 수 긁어오기                                 
            visitText = driver.find_element(By.CSS_SELECTOR, '#app-root > div > div > div > div.place_section.no_margin.OP4V8 > div.zD5Nm.undefined > div.dAsGb > span:nth-child(1) > a').text
            blogText = driver.find_element(By.CSS_SELECTOR, '#app-root > div > div > div > div.place_section.no_margin.OP4V8 > div.zD5Nm.undefined > div.dAsGb > span:nth-child(2) > a').text
            
            driver.find_element(By.XPATH, '//*[@id="app-root"]/div/div/div/div[2]/div[1]/div[2]/span[1]/a').send_keys(Keys.ENTER) # 방문자 리뷰 클릭
            time.sleep(1)
            driver.find_element(By.XPATH, '//*[@id="app-root"]/div/div/div/div[6]/div[3]/div[3]/div[1]/div[2]/div[1]/span[2]/a').send_keys(Keys.ENTER) # 최신순으로 클릭
            time.sleep(1)
        elif len(lists) == 1: # 블로그 리뷰가 없는 경우 
            visitText = driver.find_element(By.CSS_SELECTOR, '#app-root > div > div > div > div.place_section.no_margin.OP4V8 > div.zD5Nm.undefined > div.dAsGb > span > a').text
            blogText = "블로그리뷰 0"

            driver.find_element(By.XPATH, '//*[@id="app-root"]/div/div/div/div[2]/div[1]/div[2]/span/a').send_keys(Keys.ENTER) # 방문자 리뷰 클릭
            time.sleep(1)
            driver.find_element(By.XPATH, '//*[@id="app-root"]/div/div/div/div[6]/div[2]/div[3]/div[1]/div[2]/div[1]/span[2]/a').send_keys(Keys.ENTER) # 최신순으로 클릭
            time.sleep(1) 
        else:
            errorResult = "크롤링 불가"
                                        
        
        # time.sleep(random.uniform(0.8, 1.0))
        # review = extract_review(int(re.sub(r'\D', '', visitText)))  # 정규표현식을 사용하여 숫자만 추출
        review = extract_review(len(lists))

        crawlingReviewData.append(review)
        crawlingImageData.append(images)
        crawlingCategoryData.append(foodCategory)
        crawlingRatingData.append(ratingText.replace("별점", ""))
        crawlingVisitCountData.append(int(re.sub(r'\D', '', visitText)))  # 정규표현식을 사용하여 숫자만 추출
        crawlingBlogCountData.append(int(re.sub(r'\D', '', blogText)))
        count += 1
        print("----------------------------------")
        print(f'크롤링 성공! 성공: {count}, 실패: {failedCount}')
        ## 별점이 있고 없고에 따라 공백 데이터 추가해주는거 필요
    except:
        crawlingReviewData.append('x')
        crawlingImageData.append('x')
        crawlingCategoryData.append('x')
        crawlingRatingData.append('x')
        crawlingVisitCountData.append("x")
        crawlingBlogCountData.append("x")
        failedCount += 1
        print("----------------------------------")
        print(f'크롤링 실패! 성공: {count}, 실패: {failedCount}, 이유: {errorResult}')
        

    result_df = pd.DataFrame({'foodCategory': crawlingCategoryData, 'images': crawlingImageData, 'rating': crawlingRatingData, 'visitReviewCount': crawlingVisitCountData, 'blogReviewCount': crawlingBlogCountData,'review': crawlingReviewData})
# Out:
# ----------------------------------
# 크롤링 실패! 성공: 0, 실패: 1, 이유:
# ----------------------------------
# 크롤링 성공! 성공: 1, 실패: 1
# ----------------------------------
# 크롤링 성공! 성공: 2, 실패: 1
# ----------------------------------
# 크롤링 실패! 성공: 2, 실패: 2, 이유: 검색 결과 없음
# ----------------------------------
# 크롤링 성공! 성공: 3, 실패: 2
# ----------------------------------
# 크롤링 성공! 성공: 4, 실패: 2
# ----------------------------------
# 크롤링 성공! 성공: 5, 실패: 2
# ----------------------------------
# 크롤링 성공! 성공: 6, 실패: 2
# ----------------------------------
# 크롤링 실패! 성공: 6, 실패: 3, 이유: 검색 결과 없음
# ----------------------------------
# 크롤링 성공! 성공: 7, 실패: 3
# ----------------------------------
# 크롤링 실패! 성공: 7, 실패: 4, 이유: 검색 결과 없음
# ----------------------------------
# 크롤링 실패! 성공: 7, 실패: 5, 이유: 검색 결과 없음
# ----------------------------------
# 크롤링 실패! 성공: 7, 실패: 6, 이유: 검색 결과 없음
# ----------------------------------
# 크롤링 실패! 성공: 7, 실패: 7, 이유: 검색 결과 없음
# ----------------------------------
# 크롤링 성공! 성공: 8, 실패: 7
# ----------------------------------
# 크롤링 성공! 성공: 9, 실패: 7
# ----------------------------------
# 크롤링 성공! 성공: 10, 실패: 7
# ----------------------------------
# 크롤링 실패! 성공: 10, 실패: 8, 이유: 검색 결과 없음
# ----------------------------------
# 크롤링 실패! 성공: 10, 실패: 9, 이유: 검색 결과 없음
# ----------------------------------
# 크롤링 성공! 성공: 11, 실패: 9
# ----------------------------------
# 크롤링 성공! 성공: 12, 실패: 9
# 더 이상 리뷰가 없음
# ----------------------------------
# 크롤링 성공! 성공: 13, 실패: 9
# ----------------------------------
# 크롤링 실패! 성공: 13, 실패: 10, 이유: 검색 결과 없음
# 더 이상 리뷰가 없음
# 더 이상 리뷰가 없음
# ----------------------------------
# 크롤링 성공! 성공: 14, 실패: 10
# ----------------------------------
# 크롤링 성공! 성공: 15, 실패: 10
# ----------------------------------
# 크롤링 실패! 성공: 15, 실패: 11, 이유: 검색 결과 없음
# ----------------------------------
# 크롤링 실패! 성공: 15, 실패: 12, 이유: 검색 결과 없음
# 더 이상 리뷰가 없음
# ----------------------------------
# 크롤링 성공! 성공: 16, 실패: 12
# ----------------------------------
# 크롤링 실패! 성공: 16, 실패: 13, 이유: 검색 결과 없음
# ----------------------------------
# 크롤링 실패! 성공: 16, 실패: 14, 이유: 검색 결과 없음
# ----------------------------------
# 크롤링 성공! 성공: 17, 실패: 14
# ----------------------------------
# 크롤링 성공! 성공: 18, 실패: 14
# 더 이상 리뷰가 없음
# 더 이상 리뷰가 없음
# ----------------------------------
# 크롤링 성공! 성공: 19, 실패: 14
# ----------------------------------
# 크롤링 실패! 성공: 19, 실패: 15, 이유: 검색 결과 없음
# ----------------------------------
# 크롤링 실패! 성공: 19, 실패: 16, 이유: 검색 결과 없음
# 더 이상 리뷰가 없음
# 더 이상 리뷰가 없음
# ----------------------------------
# 크롤링 성공! 성공: 20, 실패: 16
# ----------------------------------
# 크롤링 실패! 성공: 20, 실패: 17, 이유: 크롤링 불가
# ----------------------------------
# 크롤링 실패! 성공: 20, 실패: 18, 이유: 크롤링 불가
# ----------------------------------
# 크롤링 성공! 성공: 21, 실패: 18
# ----------------------------------
# 크롤링 성공! 성공: 22, 실패: 18
# ----------------------------------
# 크롤링 성공! 성공: 23, 실패: 18
# ----------------------------------
# 크롤링 실패! 성공: 23, 실패: 19, 이유: 검색 결과 없음
# ----------------------------------
# 크롤링 성공! 성공: 24, 실패: 19
# ----------------------------------
# 크롤링 실패! 성공: 24, 실패: 20, 이유: 검색 결과 없음
# ----------------------------------
# 크롤링 성공! 성공: 25, 실패: 20
# ----------------------------------
# 크롤링 실패! 성공: 25, 실패: 21, 이유: 검색 결과 없음
# 더 이상 리뷰가 없음
# 더 이상 리뷰가 없음
# ----------------------------------
# 크롤링 성공! 성공: 26, 실패: 21
# ----------------------------------
# 크롤링 실패! 성공: 26, 실패: 22, 이유: 검색 결과 없음
# ----------------------------------
# 크롤링 실패! 성공: 26, 실패: 23, 이유: 검색 결과 없음
# ----------------------------------
# 크롤링 성공! 성공: 27, 실패: 23
# ----------------------------------
# 크롤링 실패! 성공: 27, 실패: 24, 이유: 검색 결과 없음
# 더 이상 리뷰가 없음
# ----------------------------------
# 크롤링 성공! 성공: 28, 실패: 24
# ----------------------------------
# 크롤링 실패! 성공: 28, 실패: 25, 이유: 검색 결과 없음
# ----------------------------------
# 크롤링 성공! 성공: 29, 실패: 25
# 더 이상 리뷰가 없음
# 더 이상 리뷰가 없음
# ----------------------------------
# 크롤링 성공! 성공: 30, 실패: 25
# ----------------------------------
# 크롤링 성공! 성공: 31, 실패: 25
# ----------------------------------
# 크롤링 실패! 성공: 31, 실패: 26, 이유: 검색 결과 없음
# ----------------------------------
# 크롤링 실패! 성공: 31, 실패: 27, 이유: 검색 결과 없음
# 더 이상 리뷰가 없음
# 더 이상 리뷰가 없음
# ----------------------------------
# 크롤링 성공! 성공:
 이유: 검색 결과 없음
# ----------------------------------
# 크롤링 성공! 성공: 240, 실패: 170
# ----------------------------------
# 크롤링 성공! 성공: 241, 실패: 170
# ----------------------------------
# 크롤링 성공! 성공: 242, 실패: 170
# ----------------------------------
# 크롤링 성공! 성공: 243, 실패: 170
# ----------------------------------
# 크롤링 성공! 성공: 244, 실패: 170
# ----------------------------------
# 크롤링 성공! 성공: 245, 실패: 170
# ----------------------------------
# 크롤링 실패! 성공: 245, 실패: 171, 이유: 검색 결과 없음
# 더 이상 리뷰가 없음
# ----------------------------------
# 크롤링 성공! 성공: 246, 실패: 171
# ----------------------------------
# 크롤링 실패! 성공: 246, 실패: 172, 이유: 검색 결과 없음
# ----------------------------------
# 크롤링 실패! 성공: 246, 실패: 173, 이유: 검색 결과 없음
# ----------------------------------
# 크롤링 실패! 성공: 246, 실패: 174, 이유: 검색 결과 없음
# ----------------------------------
# 크롤링 실패! 성공: 246, 실패: 175, 이유: 검색 결과 없음
# 더 이상 리뷰가 없음
# ----------------------------------
# 크롤링 성공! 성공: 247, 실패: 175
# ----------------------------------
# 크롤링 성공! 성공: 248, 실패: 175
# ----------------------------------
# 크롤링 실패! 성공: 248, 실패: 176, 이유: 검색 결과 없음
# ----------------------------------
# 크롤링 성공! 성공: 249, 실패: 176
# ----------------------------------
# 크롤링 성공! 성공: 250, 실패: 176
# ----------------------------------
# 크롤링 실패! 성공: 250, 실패: 177, 이유: 검색 결과 없음
# ----------------------------------
# 크롤링 실패! 성공: 250, 실패: 178, 이유: 검색 결과 없음
# ----------------------------------
# 크롤링 실패! 성공: 250, 실패: 179, 이유: 검색 결과 없음
# 더 이상 리뷰가 없음
# ----------------------------------
# 크롤링 성공! 성공: 251, 실패: 179
# 더 이상 리뷰가 없음
# 더 이상 리뷰가 없음
# ----------------------------------
# 크롤링 성공! 성공: 252, 실패: 179
# ----------------------------------
# 크롤링 성공! 성공: 253, 실패: 179
# 더 이상 리뷰가 없음
# 더 이상 리뷰가 없음
# ----------------------------------
# 크롤링 성공! 성공: 254, 실패: 179
# ----------------------------------
# 크롤링 실패! 성공: 254, 실패: 180, 이유: 검색 결과 없음
# ----------------------------------
# 크롤링 성공! 성공: 255, 실패: 180
# 더 이상 리뷰가 없음
# ----------------------------------
# 크롤링 성공! 성공: 256, 실패: 180
# 더 이상 리뷰가 없음
# 더 이상 리뷰가 없음
# ----------------------------------
# 크롤링 성공! 성공: 257, 실패: 180
# ----------------------------------
# 크롤링 성공! 성공: 258, 실패: 180
# 더 이상 리뷰가 없음
# 더 이상 리뷰가 없음
# ----------------------------------
# 크롤링 성공! 성공: 259, 실패: 180
# ----------------------------------
# 크롤링 실패! 성공: 259, 실패: 181, 이유: 검색 결과 없음
# ----------------------------------
# 크롤링 실패! 성공: 259, 실패: 182, 이유: 검색 결과 없음
# ----------------------------------
# 크롤링 성공! 성공: 260, 실패: 182
# ----------------------------------
# 크롤링 성공! 성공: 261, 실패: 182
# 더 이상 리뷰가 없음
# 더 이상 리뷰가 없음
# ----------------------------------
# 크롤링 성공! 성공: 262, 실패: 182
# ----------------------------------
# 크롤링 성공! 성공: 263, 실패: 182
# ----------------------------------
# 크롤링 성공! 성공: 264, 실패: 182
# ----------------------------------
# 크롤링 성공! 성공: 265, 실패: 182
# ----------------------------------
# 크롤링 실패! 성공: 265, 실패: 183, 이유: 검색 결과 없음
# ----------------------------------
# 크롤링 성공! 성공: 266, 실패: 183
# ----------------------------------
# 크롤링 성공! 성공: 267, 실패: 183
# ----------------------------------
# 크롤링 실패! 성공: 267, 실패: 184, 이유: 검색 결과 없음
# ----------------------------------
# 크롤링 성공! 성공: 268, 실패: 184
# ----------------------------------
# 크롤링 성공! 성공: 269, 실패: 184
# ----------------------------------
# 크롤링 성공! 성공: 270, 실패: 184
# ----------------------------------
# 크롤링 실패! 성공: 270, 실패: 185, 이유: 검색 결과 없음
# 더 이상 리뷰가 없음
# 더 이상 리뷰가 없음
# ----------------------------------
# 크롤링 성공! 성공: 271, 실패: 185
# ----------------------------------
# 크롤링 실패! 성공: 271, 실패: 186, 이유: 검색 결과 없음
# ----------------------------------
# 크롤링 성공! 성공: 272, 실패: 186
# ----------------------------------
# 크롤링 실패! 성공: 272, 실패: 187, 이유: 검색 결과 없음
# ----------------------------------
# 크롤링 실패! 성공: 272, 실패: 188, 이유: 검색 결과 없음
# ----------------------------------
# 크롤링 성공! 성공: 273, 실패: 188
# 더 이상 리뷰가 없음
# ----------------------------------
# 크롤링 성공! 성공: 274, 실패: 188
# ----------------------------------
# 크롤링 실패! 성공: 274, 실패: 189, 이유: 검색 결과 없음
# ----------------------------------
# 크롤링 실패! 성공: 274, 실패: 190, 이유: 검색 결과 없음
# ----------------------------------
# 크롤링 성공! 성공: 275, 실패: 190
# ----------------------------------
# 크롤링 성공! 성공: 276, 실패: 190
# ----------------------------------
# 크롤링 성공! 성공: 277, 실패: 190
# ----------------------------------
# 크롤링 실패! 성공: 277, 실패: 191, 이유: 검색 결과 없음
# ----------------------------------
# 크롤링 성공! 성공: 278, 실패: 191
# ----------------------------------
# 크롤링 성공! 성공: 279, 실패: 191
# ----------------------------------
# 크롤링 실패! 성공: 279, 실패: 192, 이유: 검색 결과 없음
# ----------------------------------
# 크롤링 실패! 성공: 279, 실패: 193, 이유: 검색 결과 없음
# 더 이상 리뷰가 없음
# 더 이상 리뷰가 없음
# ----------------------------------
# 크롤링 성공! 성공: 280, 실패: 193
# ----------------------------------
# 크롤링 실패! 성공: 280, 실패: 194, 이유: 검색 결과 없음
# ----------------------------------
# 크롤링 성공! 성공: 281, 실패: 194
# 더 이상 리뷰가 없음
# ----------------------------------
# 크롤링 성공! 성공: 282, 실패: 194
# ----------------------------------
# 크롤링 성공! 성공: 283, 실패: 194
# ----------------------------------
# 크롤링 성공! 성공: 284, 실패: 194
# 더 이상 리뷰가 없음
# ----------------------------------
# 크롤링 성공! 성공: 285, 실패: 194
# ----------------------------------
# 크롤링 실패! 성공: 285, 실패: 195, 이유: 검색 결과 없음
# 더 이상 리뷰가 없음
# 더 이상 리뷰가 없음
# ----------------------------------
# 크롤링 성공! 성공: 286, 실패: 195
# ----------------------------------
# 크롤링 실패! 성공: 286, 실패: 196, 이유: 검색 결과 없음
# ----------------------------------
# 크롤링 성공! 성공: 287, 실패: 196
# 더 이상 리뷰가 없음
# ----------------------------------
# 크롤링 성공! 성공: 288, 실패: 196
# ----------------------------------
# 크롤링 실패! 성공: 288, 실패: 197, 이유: 검색 결과 없음
# ----------------------------------
# 크롤링 실패! 성공: 288, 실패: 198, 이유: 검색 결과 없음
# 더 이상 리뷰가 없음
# ----------------------------------
# 크롤링 성공! 성공: 289, 실패: 198
# ----------------------------------
# 크롤링 실패! 성공: 289, 실패: 199, 이유: 검색 결과 없음
# ----------------------------------
# 크롤링 실패! 성공: 289, 실패: 200, 이유: 검색 결과 없음
# ----------------------------------
# 크롤링 성공! 성공: 290, 실패: 200
# 더 이상 리뷰가 없음
# 더 이상 리뷰가 없음
# ----------------------------------
# 크롤링 성공! 성공: 291, 실패: 200
# ----------------------------------
# 크롤링 실패! 성공: 291, 실패: 201, 이유: 검색 결과 없음
# ----------------------------------
# 크롤링 성공! 성공: 292, 실패: 201
# ----------------------------------
# 크롤링 실패! 성공: 292, 실패: 202, 이유: 검색 결과 없음
# ----------------------------------
# 크롤링 성공! 성공: 293, 실패: 202
# ----------------------------------
# 크롤링 성공! 성공: 294, 실패: 202
# ----------------------------------
# 크롤링 실패! 성공: 294, 실패: 203, 이유: 검색 결과 없음
# ----------------------------------
# 크롤링 실패! 성공: 294, 실패: 204, 이유: 검색 결과 없음
# ----------------------------------
# 크롤링 실패! 성공: 294, 실패: 205, 이유: 검색 결과 없음
# 더 이상 리뷰가 없음
# ----------------------------------
# 크롤링 성공! 성공: 295, 실패: 205
# 더 이상 리뷰가 없음
# ----------------------------------
# 크롤링 성공! 성공: 296, 실패: 205
# ----------------------------------
# 크롤링 성공! 성공: 297, 실패: 205
# ----------------------------------
# 크롤링 성공! 성공: 298, 실패: 205
# 더 이상 리뷰가 없음
# ----------------------------------
# 크롤링 성공! 성공: 299, 실패: 205
# ----------------------------------
# 크롤링 성공! 성공: 300, 실패: 205
# ----------------------------------
# 크롤링 성공! 성공: 301, 실패: 205
# ----------------------------------
# 크롤링 성공! 성공: 302, 실패: 205
# ----------------------------------
# 크롤링 실패! 성공: 302, 실패: 206, 이유: 검색 결과 없음
# ----------------------------------
# 크롤링 성공! 성공: 303, 실패: 206
# ----------------------------------
# 크롤링 실패! 성공: 303, 실패: 207, 이유: 검색 결과 없음
# ----------------------------------
# 크롤링 실패! 성공: 303, 실패: 208, 이유: 검색 결과 없음
# ----------------------------------
# 크롤링 성공! 성공: 304, 실패: 208
# 더 이상 리뷰가 없음
# 더 이상 리뷰가 없음
# ----------------------------------
# 크롤링 성공! 성공: 305, 실패: 208
# ----------------------------------
# 크롤링 성공! 성공: 306, 실패: 208
# ----------------------------------
# 크롤링 실패! 성공: 306, 실패: 209, 이유: 검색 결과 없음
# ----------------------------------
# 크롤링 실패! 성공: 306, 실패: 210, 이유: 검색 결과 없음
# ----------------------------------
# 크롤링 실패! 성공: 306, 실패: 211, 이유: 검색 결과 없음
# ----------------------------------
# 크롤링 실패! 성공: 306, 실패: 212, 이유: 검색 결과 없음
# ----------------------------------
# 크롤링 실패! 성공: 306, 실패: 213, 이유: 검색 결과 없음
# ----------------------------------
# 크롤링 실패! 성공: 306, 실패: 214, 이유: 검색 결과 없음
# ----------------------------------
# 크롤링 성공! 성공: 307, 실패: 214
# ----------------------------------
# 크롤링 성공! 성공: 308, 실패: 214
# ----------------------------------
# 크롤링 성공! 성공: 309, 실패: 214
# 더 이상 리뷰가 없음
# 더 이상 리뷰가 없음
# ----------------------------------
# 크롤링 성공! 성공: 310, 실패: 214
# ----------------------------------
# 크롤링 성공! 성공: 311, 실패: 214
# ----------------------------------
# 크롤링 실패! 성공: 311, 실패: 215, 이유: 검색 결과 없음
# ----------------------------------
# 크롤링 실패! 성공: 311, 실패: 216, 이유: 검색 결과 없음
# ----------------------------------
# 크롤링 실패! 성공: 311, 실패: 217, 이유: 검색 결과 없음
# ----------------------------------
# 크롤링 성공! 성공: 312, 실패: 217
# ----------------------------------
# 크롤링 실패! 성공: 312, 실패: 218, 이유: 검색 결과 없음
# ----------------------------------
# 크롤링 성공! 성공: 313, 실패: 218
# ----------------------------------
# 크롤링 실패! 성공: 313, 실패: 219, 이유: 검색 결과 없음
# ----------------------------------
# 크롤링 성공! 성공: 314, 실패: 219
# ----------------------------------
# 크롤링 성공! 성공: 315, 실패: 219
# 더 이상 리뷰가 없음
# 더 이상 리뷰가 없음
# ----------------------------------
# 크롤링 성공! 성공: 316, 실패: 219
# ----------------------------------
# 크롤링 실패! 성공: 316, 실패: 220, 이유: 검색 결과 없음
# ----------------------------------
# 크롤링 성공! 성공: 317, 실패: 220
# ----------------------------------
# 크롤링 실패! 성공: 317, 실패: 221, 이유: 검색 결과 없음
# ----------------------------------
# 크롤링 실패! 성공: 317, 실패: 222, 이유: 검색 결과 없음
# ----------------------------------
# 크롤링 실패! 성공: 317, 실패: 223, 이유: 검색 결과 없음
# ----------------------------------
# 크롤링 성공! 성공: 318, 실패: 223
# ----------------------------------
# 크롤링 실패! 성공: 318, 실패: 224, 이유: 검색 결과 없음
# ----------------------------------
# 크롤링 성공! 성공: 319, 실패: 224
# ----------------------------------
# 크롤링 성공! 성공: 320, 실패: 224
# ----------------------------------
# 크롤링 실패! 성공: 320, 실패: 225, 이유: 검색 결과 없음
# ----------------------------------
# 크롤링 실패! 성공: 320, 실패: 226, 이유: 검색 결과 없음
# ----------------------------------
# 크롤링 성공! 성공: 321, 실패: 226
# ----------------------------------
# 크롤링 성공! 성공: 322, 실패: 226
# ----------------------------------
# 크롤링 실패! 성공: 322, 실패: 227, 이유: 검색 결과 없음
# 더 이상 리뷰가 없음
# ----------------------------------
# 크롤링 성공! 성공: 323, 실패: 227
# ----------------------------------
# 크롤링 실패! 성공: 323, 실패: 228, 이유: 검색 결과 없음
# 더 이상 리뷰가 없음
# ----------------------------------
# 크롤링 성공! 성공: 324, 실패: 228
# ----------------------------------
# 크롤링 성공! 성공: 325, 실패: 228
# 더 이상 리뷰가 없음
# 더 이상 리뷰가 없음
# ----------------------------------
# 크롤링 성공! 성공: 326, 실패: 228
# ----------------------------------
# 크롤링 실패! 성공: 326, 실패: 229, 이유: 크롤링 불가
# ----------------------------------
# 크롤링 실패! 성공: 326, 실패: 230, 이유: 크롤링 불가
# ----------------------------------
# 크롤링 성공! 성공: 327, 실패: 230
# ----------------------------------
# 크롤링 실패! 성공: 327, 실패: 231, 이유: 검색 결과 없음
# ----------------------------------
# 크롤링 실패! 성공: 327, 실패: 232, 이유: 검색 결과 없음
# ----------------------------------
# 크롤링 성공! 성공: 328, 실패: 232
# ----------------------------------
# 크롤링 실패! 성공: 328, 실패: 233, 이유: 검색 결과 없음
# ----------------------------------
# 크롤링 실패! 성공: 328, 실패: 234, 이유: 검색 결과 없음
# ----------------------------------
# 크롤링 성공! 성공: 329, 실패: 234
# ----------------------------------
# 크롤링 성공! 성공: 330, 실패: 234
# ----------------------------------
# 크롤링 실패! 성공: 330, 실패: 235, 이유: 검색 결과 없음
# ----------------------------------
# 크롤링 성공! 성공: 331, 실패: 235
# ----------------------------------
# 크롤링 실패! 성공: 331, 실패: 236, 이유: 검색 결과 없음
# ----------------------------------
# 크롤링 성공! 성공: 332, 실패: 236
# ----------------------------------
# 크롤링 실패! 성공: 332, 실패: 237, 이유: 검색 결과 없음
# ----------------------------------
# 크롤링 성공! 성공: 333, 실패: 237
# ----------------------------------
# 크롤링 실패! 성공: 333, 실패: 238, 이유: 검색 결과 없음
# ----------------------------------
# 크롤링 실패! 성공: 333, 실패: 239, 이유: 검색 결과 없음
# ----------------------------------
# 크롤링 성공! 성공: 334, 실패: 239
# ----------------------------------
# 크롤링 성공! 성공: 335, 실패: 239
# ----------------------------------
# 크롤링 성공! 성공: 336, 실패: 239
# ----------------------------------
# 크롤링 성공! 성공: 337, 실패: 239
# 더 이상 리뷰가 없음
# ----------------------------------
# 크롤링 성공! 성공: 338, 실패: 239
# ----------------------------------
# 크롤링 실패! 성공: 338, 실패: 240, 이유: 검색 결과 없음
# ----------------------------------
# 크롤링 실패! 성공: 338, 실패: 241, 이유: 검색 결과 없음
# ----------------------------------
# 크롤링 성공! 성공: 339, 실패: 241
# ----------------------------------
# 크롤링 성공! 성공: 340, 실패: 241
# ----------------------------------
# 크롤링 실패! 성공: 340, 실패: 242, 이유: 검색 결과 없음
# ----------------------------------
# 크롤링 실패! 성공: 340, 실패: 243, 이유: 검색 결과 없음
# ----------------------------------
# 크롤링 성공! 성공: 341, 실패: 243
# ----------------------------------
# 크롤링 성공! 성공: 342, 실패: 243
# ----------------------------------
# 크롤링 성공! 성공: 343, 실패: 243
# 더 이상 리뷰가 없음
# ----------------------------------
# 크롤링 성공! 성공: 344, 실패: 243
# ----------------------------------
# 크롤링 실패! 성공: 344, 실패: 244, 이유: 검색 결과 없음
# 더 이상 리뷰가 없음
# 더 이상 리뷰가 없음
# ----------------------------------
# 크롤링 성공! 성공: 345, 실패: 244
# 더 이상 리뷰가 없음
# 더 이상 리뷰가 없음
# ----------------------------------
# 크롤링 성공! 성공: 346, 실패: 244
# ----------------------------------
# 크롤링 실패! 성공: 346, 실패: 245, 이유: 검색 결과 없음
# 더 이상 리뷰가 없음
# 더 이상 리뷰가 없음
# ----------------------------------
# 크롤링 성공! 성공: 347, 실패: 245
# ----------------------------------
# 크롤링 실패! 성공: 347, 실패: 246, 이유: 검색 결과 없음
# ----------------------------------
# 크롤링 실패! 성공: 347, 실패: 247, 이유: 검색 결과 없음
# ----------------------------------
# 크롤링 실패! 성공: 347, 실패: 248, 이유: 검색 결과 없음
# ----------------------------------
# 크롤링 실패! 성공: 347, 실패: 249, 이유: 검색 결과 없음
# ----------------------------------
# 크롤링 성공! 성공: 348, 실패: 249
# ----------------------------------
# 크롤링 성공! 성공: 349, 실패: 249
# ----------------------------------
# 크롤링 실패! 성공: 349, 실패: 250, 이유: 검색 결과 없음
# 더 이상 리뷰가 없음
# ----------------------------------
# 크롤링 성공! 성공: 350, 실패: 250
# ----------------------------------
# 크롤링 성공! 성공: 351, 실패: 250
# ----------------------------------
# 크롤링 실패! 성공: 351, 실패: 251, 이유: 검색 결과 없음
# ----------------------------------
# 크롤링 실패! 성공: 351, 실패: 252, 이유: 검색 결과 없음
# ----------------------------------
# 크롤링 성공! 성공: 352, 실패: 252
# ----------------------------------
# 크롤링 실패! 성공: 352, 실패: 253, 이유: 검색 결과 없음
# ----------------------------------
# 크롤링 실패! 성공: 352, 실패: 254, 이유: 검색 결과 없음
# ----------------------------------
# 크롤링 실패! 성공: 352, 실패: 255, 이유: 검색 결과 없음
# ----------------------------------
# 크롤링 성공! 성공: 353, 실패: 255
# ----------------------------------
# 크롤링 성공! 성공: 354, 실패: 255
# ----------------------------------
# 크롤링 성공! 성공: 355, 실패: 255
# ----------------------------------
# 크롤링 성공! 성공: 356, 실패: 255
# ----------------------------------
# 크롤링 실패! 성공: 356, 실패: 256, 이유: 검색 결과 없음
# ----------------------------------
# 크롤링 성공! 성공: 357, 실패: 256
# 더 이상 리뷰가 없음
# ----------------------------------
# 크롤링 성공! 성공: 358, 실패: 256
# ----------------------------------
# 크롤링 성공! 성공: 359, 실패: 256
# 더 이상 리뷰가 없음
# ----------------------------------
# 크롤링 성공! 성공: 360, 실패: 256
# 더 이상 리뷰가 없음
# 더 이상 리뷰가 없음
# ----------------------------------
# 크롤링 성공! 성공: 361, 실패: 256
# ----------------------------------
# 크롤링 성공! 성공: 362, 실패: 256
# ----------------------------------
# 크롤링 실패! 성공: 362, 실패: 257, 이유: 검색 결과 없음
# 더 이상 리뷰가 없음
# 더 이상 리뷰가 없음
# ----------------------------------
# 크롤링 성공! 성공: 363, 실패: 257
# ----------------------------------
# 크롤링 실패! 성공: 363, 실패: 258, 이유: 크롤링 불가
# ----------------------------------
# 크롤링 실패! 성공: 363, 실패: 259, 이유: 크롤링 불가
# ----------------------------------
# 크롤링 실패! 성공: 363, 실패: 260, 이유: 크롤링 불가
# 더 이상 리뷰가 없음
# ----------------------------------
# 크롤링 성공! 성공: 364, 실패: 260
# ----------------------------------
# 크롤링 성공! 성공: 365, 실패: 260
# ----------------------------------
# 크롤링 실패! 성공: 365, 실패: 261, 이유: 검색 결과 없음
# ----------------------------------
# 크롤링 성공! 성공: 366, 실패: 261
# ----------------------------------
# 크롤링 실패! 성공: 366, 실패: 262, 이유: 검색 결과 없음
# ----------------------------------
# 크롤링 성공! 성공: 367, 실패: 262
# ----------------------------------
# 크롤링 성공! 성공: 368, 실패: 262
# ----------------------------------
# 크롤링 성공! 성공: 369, 실패: 262
# ----------------------------------
# 크롤링 성공! 성공: 370, 실패: 262
# ----------------------------------
# 크롤링 실패! 성공: 370, 실패: 263, 이유: 검색 결과 없음
# ----------------------------------
# 크롤링 성공! 성공: 371, 실패: 263
# ----------------------------------
# 크롤링 성공! 성공: 372, 실패: 263
# ----------------------------------
# 크롤링 실패! 성공: 372, 실패: 264, 이유: 검색 결과 없음
# ----------------------------------
# 크롤링 실패! 성공: 372, 실패: 265, 이유: 검색 결과 없음
# ----------------------------------
# 크롤링 성공! 성공: 373, 실패: 265
# ----------------------------------
# 크롤링 실패! 성공: 373, 실패: 266, 이유: 검색 결과 없음
# 더 이상 리뷰가 없음
# 더 이상 리뷰가 없음
# ----------------------------------
# 크롤링 성공! 성공: 374, 실패: 266
# ----------------------------------
# 크롤링 실패! 성공: 374, 실패: 267, 이유: 검색 결과 없음
# ----------------------------------
# 크롤링 실패! 성공: 374, 실패: 268, 이유: 검색 결과 없음
# 더 이상 리뷰가 없음
# 더 이상 리뷰가 없음
# ----------------------------------
# 크롤링 성공! 성공: 375, 실패: 268
# ----------------------------------
# 크롤링 실패! 성공: 375, 실패: 269, 이유: 검색 결과 없음
# ----------------------------------
# 크롤링 실패! 성공: 375, 실패: 270, 이유: 검색 결과 없음
# ----------------------------------
# 크롤링 성공! 성공: 376, 실패: 270
# ----------------------------------
# 크롤링 성공! 성공: 377, 실패: 270
# ----------------------------------
# 크롤링 실패! 성공: 377, 실패: 271, 이유: 검색 결과 없음
# ----------------------------------
# 크롤링 실패! 성공: 377, 실패: 272, 이유: 검색 결과 없음
# ----------------------------------
# 크롤링 실패! 성공: 377, 실패: 273, 이유: 검색 결과 없음
# ----------------------------------
# 크롤링 실패! 성공: 377, 실패: 274, 이유: 검색 결과 없음
# ----------------------------------
# 크롤링 실패! 성공: 377, 실패: 275, 이유: 검색 결과 없음
# 더 이상 리뷰가 없음
# 더 이상 리뷰가 없음
# ----------------------------------
# 크롤링 성공! 성공: 378, 실패: 275
# ----------------------------------
# 크롤링 실패! 성공: 378, 실패: 276, 이유: 검색 결과 없음
# ----------------------------------
# 크롤링 성공! 성공: 379, 실패: 276
# ----------------------------------
# 크롤링 성공! 성공: 380, 실패: 276
# ----------------------------------
# 크롤링 성공! 성공: 381, 실패: 276
# ----------------------------------
# 크롤링 실패! 성공: 381, 실패: 277, 이유: 검색 결과 없음
# ----------------------------------
# 크롤링 실패! 성공: 381, 실패: 278, 이유: 검색 결과 없음
# ----------------------------------
# 크롤링 성공! 성공: 382, 실패: 278
# ----------------------------------
# 크롤링 성공! 성공: 383, 실패: 278
# ----------------------------------
# 크롤링 성공! 성공: 384, 실패: 278
# ----------------------------------
# 크롤링 성공! 성공: 385, 실패: 278
# ----------------------------------
# 크롤링 실패! 성공: 385, 실패: 279, 이유: 검색 결과 없음
# 더 이상 리뷰가 없음
# 더 이상 리뷰가 없음
# ----------------------------------
# 크롤링 성공! 성공: 386, 실패: 279
# ----------------------------------
# 크롤링 성공! 성공: 387, 실패: 279
# ----------------------------------
# 크롤링 성공! 성공: 388, 실패: 279
# ----------------------------------
# 크롤링 실패! 성공: 388, 실패: 280, 이유: 검색 결과 없음
# ----------------------------------
# 크롤링 성공! 성공: 389, 실패: 280
# ----------------------------------
# 크롤링 실패! 성공: 389, 실패: 281, 이유: 검색 결과 없음
# ----------------------------------
# 크롤링 성공! 성공: 390, 실패: 281
# 더 이상 리뷰가 없음
# 더 이상 리뷰가 없음
# ----------------------------------
# 크롤링 성공! 성공: 391, 실패: 281
# ----------------------------------
# 크롤링 성공! 성공: 392, 실패: 281
# 더 이상 리뷰가 없음
# ----------------------------------
# 크롤링 성공! 성공: 393, 실패: 281
# ----------------------------------
# 크롤링 실패! 성공: 393, 실패: 282, 이유: 검색 결과 없음
# ----------------------------------
# 크롤링 실패! 성공: 393, 실패: 283, 이유: 검색 결과 없음
# ----------------------------------
# 크롤링 성공! 성공: 394, 실패: 283
# 더 이상 리뷰가 없음
# 더 이상 리뷰가 없음
# ----------------------------------
# 크롤링 성공! 성공: 395, 실패: 283
# ----------------------------------
# 크롤링 성공! 성공: 396, 실패: 283
# 더 이상 리뷰가 없음
# ----------------------------------
# 크롤링 성공! 성공: 397, 실패: 283
# ----------------------------------
# 크롤링 성공! 성공: 398, 실패: 283
# ----------------------------------
# 크롤링 성공! 성공: 399, 실패: 283
# ----------------------------------
# 크롤링 성공! 성공: 400, 실패: 283
# ----------------------------------
# 크롤링 성공! 성공: 401, 실패: 283
# ----------------------------------
# 크롤링 성공! 성공: 402, 실패: 283
# ----------------------------------
# 크롤링 성공! 성공: 403, 실패: 283
# ----------------------------------
# 크롤링 실패! 성공: 403, 실패: 284, 이유: 검색 결과 없음
# ----------------------------------
# 크롤링 실패! 성공: 403, 실패: 285, 이유: 검색 결과 없음
# ----------------------------------
# 크롤링 실패! 성공: 403, 실패: 286, 이유: 검색 결과 없음
# ---------------------------------------------------------------------------
# TimeoutException                          Traceback (most recent call last)
# Cell In[12], line 21
#      16 url = f"https://map.naver.com/v5/search/{scrapy_df['사업장명'][i]} {scrapy_df['도로명전체주소'][i]}"
#      17 # url = f"https://map.naver.com/v5/search/걸작떡볶이제주노형점 제주특별자치도 제주시 노형9길 7"
#      18 # url = f"https://map.naver.com/v5/search/신촌도시락 제주 제주시 조천읍 신북로 88"
#      19 # url = f"https://map.naver.com/v5/search/가시림 카페 제주 서귀포시 표선면 녹산로 5번길 171"
# ---> 21 driver.get(url)
#      22 time.sleep(random.uniform(2.0, 2.5))
#      23 try:
#
# File c:\Users\windowadmin6\Desktop\Project\DataAnalysis - 복사본\venv\Lib\site-packages\selenium\webdriver\remote\webdriver.py:356, in WebDriver.get(self, url)
#     354 def get(self, url: str) -> None:
#     355     """Loads a web page in the current browser session."""
# --> 356     self.execute(Command.GET, {"url": url})
#
# File c:\Users\windowadmin6\Desktop\Project\DataAnalysis - 복사본\venv\Lib\site-packages\selenium\webdriver\remote\webdriver.py:347, in WebDriver.execute(self, driver_command, params)
#     345 response = self.command_executor.execute(driver_command, params)
#     346 if response:
# --> 347     self.error_handler.check_response(response)
#     348     response["value"] = self._unwrap_value(response.get("value", None))
#     349     return response
#
# File c:\Users\windowadmin6\Desktop\Project\DataAnalysis - 복사본\venv\Lib\site-packages\selenium\webdriver\remote\errorhandler.py:229, in ErrorHandler.check_response(self, response)
#     227         alert_text = value["alert"].get("text")
#     228     raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 229 raise exception_class(message, screen, stacktrace)
#
# TimeoutException: Message: timeout: Timed out receiving message from renderer: -0.000
#   (Session info: chrome=119.0.6045.105)
# Stacktrace:
# 	GetHandleVerifier [0x00007FF71DC082B2+55298]
# 	(No symbol) [0x00007FF71DB75E02]
# 	(No symbol) [0x00007FF71DA305AB]
# 	(No symbol) [0x00007FF71DA1E997]
# 	(No symbol) [0x00007FF71DA1E7A8]
# 	(No symbol) [0x00007FF71DA1CF0E]
# 	(No symbol) [0x00007FF71DA1D9CE]
# 	(No symbol) [0x00007FF71DA2A20F]
# 	(No symbol) [0x00007FF71DA3B551]
# 	(No symbol) [0x00007FF71DA3FC1A]
# 	(No symbol) [0x00007FF71DA1E032]
# 	(No symbol) [0x00007FF71DA3B42A]
# 	(No symbol) [0x00007FF71DAAA9C8]
# 	(No symbol) [0x00007FF71DA91E83]
# 	(No symbol) [0x00007FF71DA6670A]
# 	(No symbol) [0x00007FF71DA67964]
# 	GetHandleVerifier [0x00007FF71DF80AAB+3694587]
# 	GetHandleVerifier [0x00007FF71DFD728E+4048862]
# 	GetHandleVerifier [0x00007FF71DFCF173+4015811]
# 	GetHandleVerifier [0x00007FF71DCA47D6+695590]
# 	(No symbol) [0x00007FF71DB80CE8]
# 	(No symbol) [0x00007FF71DB7CF34]
# 	(No symbol) [0x00007FF71DB7D062]
# 	(No symbol) [0x00007FF71DB6D3A3]
# 	BaseThreadInitThunk [0x00007FFC212C7AC4+20]
# 	RtlUserThreadStart [0x00007FFC2335A351+33]

# %%
# 출력 옵션 설정 (컬럼 너비 조정)
# pd.set_option('display.max_colwidth', None) # 길이 제한 해제
# pd.set_option('display.max_colwidth', 50) # 길이 기본 값
# 백수당 제주특별자치도 제주시 구좌읍 월정1길 63
# 낙지육회제주탕탕이 제주특별자치도 제주시 진남로6길 38-1 (화북일동)
# 사라숯불구이 제주특별자치도 제주시 서사로 109
# 24시국수회관 제주특별자치도 제주시 남성로 122-1 (삼도일동)

# %%
result_df['review']

# %%
result_df.tail()

# %%
result_df.to_csv("Data/제주도식당_크롤링_3000.csv", index=False)
