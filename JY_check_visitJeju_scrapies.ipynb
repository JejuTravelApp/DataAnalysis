# %%
import pandas as pd

# %%
df = pd.read_csv("./Data/visitJeju 크롤링(~725).csv")
df
# Out:
#            title stars          mainTag                               subTag  \
# 0             미유   NaN    #한림 #옹포리 #소품샵             #핸드메이드소품 #키링 #우산 #지갑 #쇼핑
# 1           마야블루   NaN  #쇼핑 #라탄 #원데이클래스                        #관광기념품 #상점/상가
# 2          몸냥공작소   NaN     #공방 #기념품 #쇼핑                        #관광기념품 #상점/상가
# 3           은인마켙   NaN     #함덕 #소품샵 #식기                                  #잡화
# 4         뱅뱅와인마켓   NaN   #제주시내 #오라동 #와인                                 #샴페인
# ..           ...   ...              ...                                  ...
# 720  윌로우씨 제주캔들공방   NaN     #캔들 #기념품 #쇼핑                        #관광기념품 #상점/상가
# 721       제주비치펜션   NaN    #휴식 #숙소 #휴양펜션  #펜션 #주차장 #해수욕장 #자연경관 #바비큐 #해변 #해안도로
# 722         고사리숲   NaN   #체험관광 #아이 #화장품                    #자연경관 #체험 #숲 #어린이
# 723         대수포구   NaN   #포구 #해변 #문화유적지                          #자연경관 #역사유적
# 724         종종제주   NaN    #조천 #선흘리 #소품샵                #잡화 #문구류 #핸드메이드소품 #쇼핑
#
# ...

# %%
# 컬럼별 null 확인
df.count()
# Out:
# title            725
# stars              6
# mainTag          725
# subTag           692
# text             723
# BodyRightText    725
# dtype: int64

# %%
df[df['stars'].notnull()]
# Out:
#         title         stars         mainTag  \
# 19      마니주펜션  별점(5점만점에 4점)   #숙소 #펜션 #휴양펜션
# 36      휘슬락호텔  별점(5점만점에 4점)  #호텔 #숙소 #오션뷰호텔
# 166     바다의향기  별점(5점만점에 4점)     #펜션 #숙소 #민박
# 419     알앤비타운  별점(5점만점에 1점)    #리조트 #숙소 #펜션
# 623  사계 용머리해안  별점(5점만점에 4점)     #부모 #커플 #혼자
# 710  제주오름승마랜드  별점(5점만점에 1점)   #승마 #액티비티 #커플
#
#                                                 subTag  \
# 19             #자연경관 #바비큐 #공공와이파이존 #해수욕장 #해안도로 #해변 #가족
# 36                    #공공와이파이존 #수영장 #주차장 #양식레스토랑 #조식포함
# 166                    #농어촌민박 #단체여행객 #주차장 #공공와이파이존 #해변
# 419                           #휴양펜션 #공공와이파이존 #바비큐 #주차장
# 623  #친구 #경관/포토 #휴식/힐링 #문화유적지 #사계절 #청년 #중/장년 #노년 #휴...
# 710                 #맑음 #오름 #체험 #도보여행 #도보 #레저/체험 #어트랙션
#
#                                                   text  \
# 19   제주국제공항에서 차로 약 15분 거리에 위치한 마니주펜션은 제주올레 17코스를 따라...
# 36   달콤한 여행의 추억을 수집하고 싶은 당신에게 신비로운 제주의 바다가 한 폭의 그림으...
# 166  낭만과 추억이 가득한 아름다운 바다의 향기 펜션입니다\n산방산과 송악산 사이에 위치...
# ...

# %% [markdown]
# stars 컬럼은 NaN이 너무 많아서 사용하기 어려워보임
# ?? mainTag와 subTag는 중복되는 태그 제외하고 합쳐서 하나의 컬럼으로 사용할지 / 앱 view로 구분 지어서 보여주기 위해 그대로 둘지

# %%
# pd.set_option('display.max_colwidth', None) # 길이 제한 해제
pd.reset_option('display.max_colwidth')         # 길이 제한 설정

# %%
df['BodyRightText']
# Out:
# 0      소개-숲속 별장처럼 꾸며진 소품 가게, 이용 시간-평일 : 11:00 ~ 18:00...
# 1      소개-마야블루는 제주 시내의 주택가 사이에 작은 간판으로 자신의 존재를 알리고 있다...
# 2      소개-귀엽고 제주스러운 유니크한 소품가게, 상세 정보-토, 일, 공휴일 휴무, 이용...
# 3      소개-자개, 유리 등 다양한 식기류를 만나볼 수 있는 소품샵, 상세 정보-매주 수요...
# 4      소개-공항 인근에 위치한 대형 와인판매점, 이용 시간-평일 : 10:30 ~ 21:...
#                              ...
# 720    소개-제주스러운 기념품으로 캔들,방향제를 판매하는 곳이다., 상세 정보-동문시장(주...
# 721    소개-전 객실이 제주의 바다와 노을을 한눈에 볼 수 있는 구조도 되어 있는 곳, 이...
# 722                       소개-립밤 만들기, 비누 만들기 체험을 할 수 있는 곳
# 723                                소개-비양도가 보이는 작고 아담한 포구
# 724    소개-조용한 산간 마을에서 만나는 아기자기한 제주소품샵, 이용 시간-평일 : 10:...
# Name: BodyRightText, Length: 725, dtype: object

# %% [markdown]
# ### BodyRightText Column
# 소개, (상세정보), 이용시간, 요금정보, 장소특성, 평균 소요 시간, 경사도(난이도) (취급품목), (택배배송여부), (편의시설), (장애인 활동 보조 필요성) 등
# 컬럼을 이루고 있는 보조 제목들(-)을 어떻게 구분지을지 확인해야할듯.
# BodyRightText Column 내의 보조 제목들을 각각 데이터프레임의 컬럼으로 만들어서 분리하는게 좋아보임.
